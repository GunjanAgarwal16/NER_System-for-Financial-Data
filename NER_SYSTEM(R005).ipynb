# %% [markdown]
# # 1. Problem Analysis
#
# Named Entity Recognition (NER) is a crucial tool for extracting structured information from unstructured text. In this project, we aim to create an NER system to analyze financial reports of electronics companies, starting with Apple.
#
# ### Context:
# The system processes reports such as:
# - **10-Q Reports**: Quarterly reports with financial performance.
# - **10-K Reports**: Annual reports detailing company performance.
#
# ### Initial Setup:
# - The original reports were in **HTML format**.
# - Converted to **PDF** for processing using online converter.
#
# ### Objectives:
# 1. Extract meaningful entities like:
#    - Company names (e.g., Apple Inc.)
#    - Monetary values (e.g., revenue, profit)
#    - Financial events (e.g., stock splits)
#    - Dates (e.g., fiscal years)
# 2. Lay the foundation to scale the system for other electronics companies like Samsung and Sony.
#
# ### Challenges:
# 1. Financial text contains jargon, abbreviations, and technical terms.
# 2. Preprocessing complex reports to remove noise.
# 3. Starting with limited data (only two Apple reports).

# %% [markdown]
# # 2. Data Collection and Preprocessing
#
# ### Data Collection:
# 1. Financial reports for **Apple Inc.** were obtained in **HTML format**.
# 2. These HTML reports were converted to **PDF** using online converter for easier text extraction.
#
# ### Preprocessing Steps:
# 1. **Text Extraction**:
#    - Extracted raw text from PDF reports using PyPDF2.
#    - Combined text from both reports into a single dataset.
#
# 2. **Cleaning the Text**:
#    - Converted text to lowercase for uniformity.
#    - Removed special characters and punctuation.
#    - Replaced common abbreviations with their full forms (e.g., "$" → "USD").
#    - Removed stopwords like "the", "and", "is" for better focus on meaningful words.
#
# 3. **Tokenization**:
#    - Split sentences into words for structured processing.
#    - Example:
#      - Raw: "Apple Inc. reported revenue of $123 billion."
#      - Processed: `['apple', 'inc', 'reported', 'revenue', 'usd', '123', 'billion']`.
#
# These steps ensure the dataset is clean and ready for annotation and modeling.

# %%
# !pip install pyPDF2
# !pip install streamlit
# Out:
# Requirement already satisfied: pyPDF2 in /usr/local/lib/python3.11/dist-packages (3.0.1)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.41.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.21.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
# importing all the libraries needed for this project
import re
import nltk
from PyPDF2 import PdfReader
import spacy
from spacy.tokens import DocBin
import streamlit as st

# downloading nltk resources for tokenization and stopwords removal
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# function to extract text from pdf files
def extract_text_from_pdf(file_path):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# %%
# function to clean text: removes punctuation, converts to lowercase, and replaces abbreviations
def clean_text(text):
    text = text.lower()  # converting all text to lowercase
    text = re.sub(r"[^a-zA-Z0-9\s]", " ", text)  # removing special characters and punctuation

    # replacing common financial abbreviations with full forms
    abbreviations = {
        "$": "usd",
        "ipo": "initial public offering",
        "ge": "general electric",
        "eps": "earnings per share"
    }
    for abbr, full_form in abbreviations.items():
        text = re.sub(r'\b' + re.escape(abbr) + r'\b', full_form, text)

    # removing stopwords
    stop_words = set(nltk.corpus.stopwords.words('english'))
    words = [word for word in nltk.word_tokenize(text) if word not in stop_words]
    return " ".join(words)

# %%
import nltk
nltk.download('punkt_tab')

# extracting text from the two pdf reports
file_path_10q = '/content/drive/MyDrive/nmims/sem2/llm/assignment 1/data new/1-0-q apple.pdf'
file_path_10k = '/content/drive/MyDrive/nmims/sem2/llm/assignment 1/data new/1-0-k apple.pdf'

text_10q = extract_text_from_pdf(file_path_10q)
text_10k = extract_text_from_pdf(file_path_10k)

# cleaning the extracted text
cleaned_text_10q = clean_text(text_10q)
cleaned_text_10k = clean_text(text_10k)

# combining both cleaned texts into one dataset
combined_text = cleaned_text_10q + " " + cleaned_text_10k
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# # 3. Model Development
#
# ### Steps:
# 1. **Pre-trained Model**:
#    Used SpaCy’s `en_core_web_sm` pre-trained NER model. It recognizes basic entities like:
#    - Organizations (ORG)
#    - Money values (MONEY)
#    - Dates (DATE)
#
# 2. **Custom Training**:
#    - Annotated domain-specific financial text..
#    - Trained a new NER model using SpaCy with a custom dataset.
#
# ### Challenges:
# 1. Small training dataset (requires expansion).
# 2. Technical terms and abbreviations in financial documents.

# %%
# loading a pretrained model
import spacy

model = spacy.load("en_core_web_sm")  # loading a pretrained spacy model

# preparing text for entity extraction
k = ""
for t in combined_text.split():  # split combined text into words
    k += t + " "  # converting tokens back to a single string

doc = model(k)  # process the text using the spacy model

# extracting entities from the text
entities = [(ent.text, ent.label_) for ent in doc.ents]
print("extracted entities:")
for entity, label in entities:
    print(f"{entity}: {label}")
# Out:
# Streaming output truncated to the last 5000 lines.
# july 1 2017: DATE
# 24 2016: DATE
# 43: CARDINAL
# 700: CARDINAL
# 485: CARDINAL
# 44: CARDINAL
# 678: CARDINAL
# 518: CARDINAL
# 31 500: CARDINAL
# 24: CARDINAL
# 500 728: CARDINAL
# 48: CARDINAL
# 242: CARDINAL
# 54: CARDINAL
# 305: CARDINAL
# 153: CARDINAL
# july 1 2017: DATE
# 162 million: CARDINAL
# 24 2016: TIME
# 163 million: CARDINAL
# july 1 2017: DATE
# 24 2016: DATE
# 1 3 billion 1 5 billion: MONEY
# 326 million: CARDINAL
# 160 million: CARDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# 10: CARDINAL
# july 1 2017: DATE
# 24 2016: TIME
# one: CARDINAL
# 10: CARDINAL
# 10: CARDINAL
# 46 63: CARDINAL
# july 1 2017: DATE
# 24 2016: DATE
# july 1 2017: DATE
# three: CARDINAL
# 10: CARDINAL
# 39 19: DATE
# 24 2016: TIME
# two: CARDINAL
# 10: CARDINAL
# 47 21: DATE
# apple inc q3 2017: ORG
# 10: CARDINAL
# 3: CARDINAL
# july 1 2017: DATE
# july 1 2017: DATE
# 24 2016: TIME
# 12: CARDINAL
# 529: CARDINAL
# 10 185: CARDINAL
# 49 491: CARDINAL
# 44 543: CARDINAL
# 6: CARDINAL
# 6: CARDINAL
# 517: CARDINAL
# 68: CARDINAL
# 981: CARDINAL
# 245: CARDINAL
# 39: CARDINAL
# 695: CARDINAL
# 34 235: CARDINAL
# 29: CARDINAL
# 27: CARDINAL
# july 1 2017: DATE
# 24 2016: DATE
# 30: CARDINAL
# 26: CARDINAL
# 8 407: CARDINAL
# 10: CARDINAL
# 055: CARDINAL
# 38 598: CARDINAL
# 36: CARDINAL
# 074: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017june 25: DATE
# 1: CARDINAL
# 833: CARDINAL
# 963: CARDINAL
# 602: CARDINAL
# 409: CARDINAL
# 1: CARDINAL
# 1 006: CARDINAL
# 185 263: CARDINAL
# 228: CARDINAL
# 1 036: CARDINAL
# 540: CARDINAL
# 364: CARDINAL
# 1: CARDINAL
# 4: CARDINAL
# july 1 2017: DATE
# 24 2016: DATE
# july 1 2017: DATE
# 24 2016: DATE
# 7: CARDINAL
# 2: CARDINAL
# 344: CARDINAL
# 5: CARDINAL
# 806: CARDINAL
# 106: CARDINAL
# 100 100 100 100: CARDINAL
# 7 458: CARDINAL
# 5: CARDINAL
# 014: CARDINAL
# 2: CARDINAL
# 444: CARDINAL
# 9: CARDINAL
# 5: CARDINAL
# 806: CARDINAL
# 3: CARDINAL
# 206 apple inc q3: MONEY
# 2017: DATE
# 10 q 11note 5: DATE
# july 1 2017: DATE
# 8 6 billion 2 6 billion: MONEY
# september 24 2016: DATE
# 7 7 billion 2 8 billion: MONEY
# 1 3 billion: MONEY
# july 1 2017: DATE
# 24 2016: DATE
# next 12 months: DATE
# august 30 2016: DATE
# european commission: ORG
# 1991: DATE
# irish: NORP
# two: CARDINAL
# june 2003: DATE
# december 2014: DATE
# irish: NORP
# january 2015: DATE
# general court court: ORG
# union ireland: PERSON
# european commission: ORG
# 13 billion: CARDINAL
# european: NORP
# irish: NORP
# 6: CARDINAL
# july 1 2017: DATE
# 24 2016: DATE
# 12 0 billion: MONEY
# nine months: DATE
# 1 01: DATE
# 1 2017: DATE
# 24 2016: TIME
# nine months ended july 1 2017: DATE
# nine months ended july 1: DATE
# 90 days: DATE
# 143: CARDINAL
# 90 days: DATE
# 12: CARDINAL
# 1 846: CARDINAL
# 8: CARDINAL
# 4: CARDINAL
# 009 162: CARDINAL
# 3 866: CARDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# july 1 2017: DATE
# 96 6 billion: QUANTITY
# quarterly: DATE
# australian: NORP
# australian: NORP
# british: NORP
# japanese: NORP
# annually: DATE
# denominated swiss franc: ORG
# july 1 2017: DATE
# 24 2016: DATE
# 1 2017: DATE
# 24 2016: DATE
# millions: CARDINAL
# millions: CARDINAL
# 2013: DATE
# 17 0 billion: MONEY
# 2018 2018 2: DATE
# 1: CARDINAL
# 1: CARDINAL
# 1: CARDINAL
# 3 850: CARDINAL
# 2018 2043: DATE
# 12: CARDINAL
# 500: CARDINAL
# 91: CARDINAL
# 91 2014: DATE
# 12 0 billion: MONEY
# 2019 2019: DATE
# 0: CARDINAL
# 86: CARDINAL
# 1 09: CARDINAL
# 2: CARDINAL
# 2019 2044: DATE
# 4: CARDINAL
# 48 2015: DATE
# 27 3 billion: MONEY
# 2019 2020: DATE
# 87: CARDINAL
# 1 87: CARDINAL
# 0: CARDINAL
# 2019 2045: DATE
# 28: CARDINAL
# 28: CARDINAL
# 24 9 billion: MONEY
# 2019 2021: DATE
# 2: CARDINAL
# 0: CARDINAL
# 91: CARDINAL
# 1 95: CARDINAL
# 1 100: CARDINAL
# 2018 2046: DATE
# 23: CARDINAL
# 610: CARDINAL
# 78: CARDINAL
# 23: CARDINAL
# 609: CARDINAL
# 1: CARDINAL
# 58 second quarter 2017: DATE
# 10 0 billion: MONEY
# 2019: DATE
# 2020: CARDINAL
# 2022 1: DATE
# 1 68: CARDINAL
# 1 550: CARDINAL
# 2019: DATE
# 1: CARDINAL
# 2020 1: DATE
# 1 38: CARDINAL
# 2 500: CARDINAL
# 2022 1: DATE
# 3 000: CARDINAL
# 2024 1: DATE
# 750: CARDINAL
# 1 98: CARDINAL
# 3 350: CARDINAL
# 2027 2: DATE
# 250: CARDINAL
# 2 12: CARDINAL
# 4 250: CARDINAL
# 2047 1: DATE
# 26 second quarter 2017: DATE
# 1 0 billion: MONEY
# 4 300: CARDINAL
# 2047 1: DATE
# 4 30 third quarter 2017: DATE
# 7 0 billion: MONEY
# 2020: DATE
# 2022: DATE
# 1 53: CARDINAL
# 1 800: CARDINAL
# 2020 1: DATE
# 1 84: CARDINAL
# 2 300: CARDINAL
# 2 34: CARDINAL
# 2 850: CARDINAL
# 2024 1: DATE
# 750: CARDINAL
# 2 16: CARDINAL
# 3 200: CARDINAL
# 2 34 third quarter 2017: DATE
# 2 5 billion: MONEY
# 0 875: CARDINAL
# 2025 1: DATE
# 3 03: CARDINAL
# 1 375: CARDINAL
# 3 37 third quarter 2017: DATE
# 1 0 billion: MONEY
# 3 000: CARDINAL
# 3 03: CARDINAL
# 96: CARDINAL
# 589: CARDINAL
# 78 384: CARDINAL
# 210 174: CARDINAL
# 20 717: CARDINAL
# 6: CARDINAL
# 3 500: CARDINAL
# 89: CARDINAL
# 75 427: CARDINAL
# apple inc q3 2017: ORG
# 10 q 13to: DATE
# third quarter 2017: DATE
# 2024 2027: DATE
# 2 75 billion: MONEY
# entire third quarter 2017: DATE
# 2 5 billion euro: QUANTITY
# second quarter 2017: DATE
# 2020 2022: DATE
# 2024 2027: DATE
# 6 5 billion: MONEY
# japanese: NORP
# july 1 2017: DATE
# 24 2016: TIME
# 1 5 billion 1 9 billion: MONEY
# 2: CARDINAL
# 574 million: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# 393 million 975 million: MONEY
# three nine month: DATE
# june 25 2016: DATE
# july 1 2017: DATE
# 24 2016: DATE
# 2: CARDINAL
# 98 3 billion: MONEY
# 7: CARDINAL
# 2017 third quarter: DATE
# 3: CARDINAL
# 281 second quarter: DATE
# 2 988 first quarter: DATE
# 3 042: CARDINAL
# 1 77: DATE
# 3: CARDINAL
# 071 third quarter: DATE
# 2: CARDINAL
# first quarter: DATE
# 52: CARDINAL
# 2 898: CARDINAL
# 2 18 11 965: DATE
# 2017: DATE
# 175 billion 210 billion: MONEY
# 158 billion: MONEY
# july 1 2017: DATE
# 10b5 1 securities exchange: MONEY
# 1934: CARDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# nine months ended july 1 2017 year ended september: DATE
# 2016: DATE
# thousands: CARDINAL
# millions: CARDINAL
# august 2017: DATE
# 598: CARDINAL
# february 2017: DATE
# may 2017: DATE
# 949: CARDINAL
# november 2016: DATE
# february 2017: DATE
# 157: CARDINAL
# 117: CARDINAL
# august 2016: DATE
# november 2016: DATE
# 850: CARDINAL
# 111: CARDINAL
# 73 3 000: DATE
# august 2016: DATE
# 452: CARDINAL
# november 2015: DATE
# april 2016: DATE
# 122: CARDINAL
# 103: CARDINAL
# 1: CARDINAL
# 2017: DATE
# august 2017 2: DATE
# 17 5 million: CARDINAL
# second quarter 2017: DATE
# 4 million: CARDINAL
# third quarter 2017: DATE
# thousands: CARDINAL
# 2017 third quarter: DATE
# 356: CARDINAL
# 24 4: DATE
# 500 second quarter 31: DATE
# 070: CARDINAL
# 128: CARDINAL
# 74 4: DATE
# 001 first quarter 44: DATE
# 333: CARDINAL
# 112: CARDINAL
# 78 5: CARDINAL
# 105: CARDINAL
# 13: CARDINAL
# 2016 fourth quarter: DATE
# 104: ORG
# 97 3 000 third quarter: DATE
# 41: CARDINAL
# 97: CARDINAL
# second: ORDINAL
# quarter 71: DATE
# 97 54 7 000 first quarter 25: DATE
# 115: CARDINAL
# 45 3 000: CARDINAL
# 167: CARDINAL
# 567 17: CARDINAL
# 8: CARDINAL
# two: CARDINAL
# 2017: DATE
# 10 q 15the: DATE
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months: DATE
# july 1 2017 june 25 2016: DATE
# 1 2017: DATE
# 25 2016: DATE
# 148: CARDINAL
# 131: CARDINAL
# 657: CARDINAL
# 785: CARDINAL
# 73: CARDINAL
# 106: CARDINAL
# 630: CARDINAL
# 419: CARDINAL
# 364: CARDINAL
# 112: CARDINAL
# 127: CARDINAL
# 123: CARDINAL
# 3: CARDINAL
# 1: CARDINAL
# 48: CARDINAL
# 20: CARDINAL
# 37 129: CARDINAL
# 633: CARDINAL
# 1 188: CARDINAL
# nine months ended july 1: DATE
# millions: CARDINAL
# 2016: DATE
# 578: CARDINAL
# 38: CARDINAL
# 38 1: CARDINAL
# 283: CARDINAL
# 1: CARDINAL
# 37: CARDINAL
# 1 448: CARDINAL
# 3 7 548 552: DATE
# 41: CARDINAL
# 1: CARDINAL
# 005: CARDINAL
# 1 179: CARDINAL
# july 1 2017: DATE
# 619: CARDINAL
# 95: CARDINAL
# 169: CARDINAL
# 545: CARDINAL
# 9: CARDINAL
# 328 1 million: CARDINAL
# july 1 2017: DATE
# four years: DATE
# two: CARDINAL
# two: CARDINAL
# 10b5 1: CARDINAL
# three months ended july 1 2017: DATE
# 16 officers: QUANTITY
# angela ahrendts timothy cook: PERSON
# maestri daniel riccio philip: ORG
# 10b5 1: DATE
# apple inc q3 2017: ORG
# 10: CARDINAL
# nine months ended july 1 2017: DATE
# thousands: CARDINAL
# millions: CARDINAL
# 99: CARDINAL
# 089: CARDINAL
# 97 54: DATE
# 48: CARDINAL
# 120 09: CARDINAL
# 41: CARDINAL
# 95: CARDINAL
# 4: CARDINAL
# 779: MONEY
# 106 75: DATE
# july 1 2017: DATE
# 100: CARDINAL
# 59: CARDINAL
# 14: CARDINAL
# 488: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# 2 8 billion: MONEY
# three nine month: DATE
# june 25 2016: DATE
# 2 0 billion: MONEY
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017june 25: DATE
# 216: CARDINAL
# 188: CARDINAL
# 662: CARDINAL
# 583: CARDINAL
# 566: CARDINAL
# 479: CARDINAL
# 1: CARDINAL
# 730: CARDINAL
# 1 413: CARDINAL
# 411: CARDINAL
# 1 184: CARDINAL
# 1: CARDINAL
# 3 180: CARDINAL
# 380 million: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# 321 million: CARDINAL
# three nine month periods ended june 25 2016: DATE
# july 1 2017: DATE
# 9 0 billion: MONEY
# 6 years: DATE
# 10: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017june 25: DATE
# 4: CARDINAL
# 985: CARDINAL
# 3: CARDINAL
# 780: CARDINAL
# 932: CARDINAL
# 1: CARDINAL
# 3: CARDINAL
# 496: CARDINAL
# 3: CARDINAL
# 897: CARDINAL
# 4 299: DATE
# 4: CARDINAL
# 255: CARDINAL
# 4: CARDINAL
# 299: CARDINAL
# 4: CARDINAL
# 255: CARDINAL
# third: ORDINAL
# third: ORDINAL
# k: GPE
# china: GPE
# 2017: DATE
# 10: CARDINAL
# one: CARDINAL
# asia: LOC
# 150 days: DATE
# july 1 2017: DATE
# 8 5 billion: MONEY
# 10 years: DATE
# multi year: DATE
# 1: CARDINAL
# 1a: CARDINAL
# 10: CARDINAL
# one: CARDINAL
# 2017: DATE
# 10: CARDINAL
# samsung electronics co ltd et al: ORG
# august 24 2012: DATE
# 1 05 billion: MONEY
# samsung electronics co ltd affiliated: ORG
# united states: GPE
# california: GPE
# san jose: GPE
# march 6 2014: DATE
# approximately 930 million: CARDINAL
# may 18 2015: DATE
# approximately 548 million: CARDINAL
# samsung: ORG
# 548 million: CARDINAL
# december 2015: DATE
# december 6 2016: DATE
# supreme court: ORG
# 548 million: CARDINAL
# february 7 2017: DATE
# 11: CARDINAL
# china: GPE
# japan: GPE
# asia pacific americas: LOC
# north south america europe: LOC
# european: NORP
# india: GPE
# middle east africa: LOC
# china: GPE
# hong kong: GPE
# taiwan: GPE
# asia pacific: LOC
# asian: NORP
# one: CARDINAL
# 1: CARDINAL
# 8 2016: DATE
# 10: CARDINAL
# third: ORDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017june 25: DATE
# 20: CARDINAL
# 376: CARDINAL
# 17: CARDINAL
# 73: CARDINAL
# 501: CARDINAL
# 66: CARDINAL
# 384: CARDINAL
# 6: CARDINAL
# 5: CARDINAL
# 23: CARDINAL
# 582: CARDINAL
# 21: CARDINAL
# 587 europe: PRODUCT
# 10: CARDINAL
# 9: CARDINAL
# 643: CARDINAL
# 41: CARDINAL
# 929: CARDINAL
# 39: CARDINAL
# 2: CARDINAL
# 12 571 12 047 greater china: PERCENT
# 8: CARDINAL
# 34: CARDINAL
# 963: CARDINAL
# 39 707: CARDINAL
# 3 002: CARDINAL
# 3: CARDINAL
# 415: CARDINAL
# 13: CARDINAL
# 402: CARDINAL
# 15: CARDINAL
# japan: GPE
# 3: CARDINAL
# 3: CARDINAL
# 529: CARDINAL
# 13: CARDINAL
# 875: CARDINAL
# 12 604: PRODUCT
# 1 624: CARDINAL
# 6: CARDINAL
# 334: CARDINAL
# asia pacific: LOC
# 2: CARDINAL
# 2: CARDINAL
# 12: CARDINAL
# 387: CARDINAL
# 10 982: CARDINAL
# 892: CARDINAL
# 4: CARDINAL
# 430: CARDINAL
# 3 880: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# 25 2016: DATE
# millions: CARDINAL
# three months ended nine months ended july 1 2017june 25: DATE
# 14: CARDINAL
# 13: CARDINAL
# 58 928: PERCENT
# 2: CARDINAL
# 2: CARDINAL
# 7 475: CARDINAL
# 1: CARDINAL
# 511: CARDINAL
# 190: CARDINAL
# 10: CARDINAL
# 10: CARDINAL
# 105: CARDINAL
# 224: CARDINAL
# 48: CARDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# 2: CARDINAL
# quarterly: DATE
# 10: CARDINAL
# 1995: DATE
# 1a: CARDINAL
# 10: CARDINAL
# annual: DATE
# 10 k year ended september: DATE
# 10: CARDINAL
# u securities exchange commission: ORG
# sec: ORG
# 10: CARDINAL
# particular years quarters months: DATE
# fiscal years ended september: DATE
# quarters months: DATE
# fiscal years: DATE
# apple inc wholly: ORG
# annual: DATE
# 10: CARDINAL
# quarterly: DATE
# 10: CARDINAL
# 8: CARDINAL
# 13: CARDINAL
# 1934: CARDINAL
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# 100: CARDINAL
# 1580: DATE
# washington: GPE
# 20549: DATE
# sec: ORG
# 1 800: CARDINAL
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# third: ORDINAL
# mac apple watch: ORG
# third: ORDINAL
# third: ORDINAL
# mac windows: PERSON
# third: ORDINAL
# third: ORDINAL
# 2017: DATE
# 10: CARDINAL
# 21business: CARDINAL
# first quarter: DATE
# quarters fiscal year: DATE
# seasonal: DATE
# fiscal period company fiscal year: DATE
# 53 week: DATE
# last saturday: DATE
# fiscal year 2017: DATE
# 53 weeks end: DATE
# september 30 2017 14th week: DATE
# first quarter 2017: DATE
# every five six years: DATE
# fiscal quarters calendar quarters third quarter fiscal 2017: DATE
# 7 3 1 billion third quarter 2017: MONEY
# quarter 2016: DATE
# year year: DATE
# third quarter 2017: DATE
# quarter 2016 third quarter 2017: DATE
# 10 5 inch: QUANTITY
# 12 9 inch: QUANTITY
# new imac: GPE
# december 2017: DATE
# 11: CARDINAL
# 4: CARDINAL
# 2017: DATE
# 7 5 billion: MONEY
# 3 4 billion third: MONEY
# quarter 2017: DATE
# 8 0 billion: MONEY
# 2 5 billion euro: MONEY
# apple inc q3 2017: ORG
# 10: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# millions: CARDINAL
# three months ended nine months ended july 1: DATE
# july 1 2017june 25 2016: DATE
# 20: CARDINAL
# 17: CARDINAL
# 963: CARDINAL
# 73: CARDINAL
# 501: CARDINAL
# 66: CARDINAL
# 384: CARDINAL
# 11: CARDINAL
# 10 675: DATE
# 9: CARDINAL
# 643: CARDINAL
# 41: CARDINAL
# 929: CARDINAL
# 39: CARDINAL
# 8: CARDINAL
# 848: CARDINAL
# 39: CARDINAL
# 707: CARDINAL
# 12: CARDINAL
# japan: GPE
# 3 624: CARDINAL
# 3: CARDINAL
# 529: CARDINAL
# 3: CARDINAL
# 13: CARDINAL
# 875: CARDINAL
# 12: CARDINAL
# 2: CARDINAL
# 12: CARDINAL
# 10: CARDINAL
# 982 13: CARDINAL
# 45: CARDINAL
# 408: CARDINAL
# 42: CARDINAL
# 358: CARDINAL
# 176: CARDINAL
# 655: CARDINAL
# 168: CARDINAL
# 787 5: PRODUCT
# 1 24: CARDINAL
# 24: CARDINAL
# 1 4: DATE
# 4: CARDINAL
# 876: CARDINAL
# 2: CARDINAL
# 391: CARDINAL
# 16: CARDINAL
# 1: CARDINAL
# 17: CARDINAL
# 9: CARDINAL
# 2 7 266: DATE
# 5: CARDINAL
# 22: CARDINAL
# 21: CARDINAL
# 479: CARDINAL
# 18: CARDINAL
# 19: CARDINAL
# 219: CARDINAL
# 23: CARDINAL
# 9: CARDINAL
# 8: CARDINAL
# 10: CARDINAL
# 45: CARDINAL
# 408: CARDINAL
# 42: CARDINAL
# 358: CARDINAL
# 176: CARDINAL
# 655: CARDINAL
# 168: CARDINAL
# 787: CARDINAL
# 5: CARDINAL
# 41: CARDINAL
# 399: CARDINAL
# 170: CARDINAL
# 079: CARDINAL
# 166: CARDINAL
# 371 2: CARDINAL
# 11: CARDINAL
# 424: CARDINAL
# 9: DATE
# 950: CARDINAL
# 33: CARDINAL
# 36: CARDINAL
# 4: CARDINAL
# 4: CARDINAL
# 252: CARDINAL
# 865: CARDINAL
# 13: CARDINAL
# 598: CARDINAL
# 2: CARDINAL
# 3: CARDINAL
# third: ORDINAL
# 2017: DATE
# 10: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# millions: CARDINAL
# three months ended nine months ended july 1: DATE
# july 1 2017: DATE
# 25 2016: DATE
# 24: CARDINAL
# 24: CARDINAL
# 540: CARDINAL
# 55: CARDINAL
# 64: CARDINAL
# 64: CARDINAL
# 41: CARDINAL
# 399: CARDINAL
# 170: CARDINAL
# 079: CARDINAL
# 166: CARDINAL
# 371: CARDINAL
# 2: CARDINAL
# third quarter first nine months 2017: DATE
# 2016: DATE
# third quarter first nine months 2017: DATE
# 2016: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# millions: CARDINAL
# three months ended nine months ended july 1 2017: DATE
# 1 2017 june 25 2016: DATE
# 4: CARDINAL
# 4: CARDINAL
# 876: CARDINAL
# 2: CARDINAL
# 391: CARDINAL
# 16: CARDINAL
# 11: CARDINAL
# 12: CARDINAL
# 8 10: TIME
# 11: CARDINAL
# 424: CARDINAL
# 9: DATE
# 950: CARDINAL
# 33: CARDINAL
# 36: CARDINAL
# 323 8: PRODUCT
# third quarter 2017: DATE
# 2016: DATE
# year year: DATE
# first nine months 2017: DATE
# third quarter first nine months 2017: DATE
# 2016 mac: QUANTITY
# three nine month: DATE
# july 1 2017: DATE
# millions: CARDINAL
# three months ended nine months ended july 1 2017: DATE
# 25 2016: DATE
# july 1 2017: DATE
# 25 2016: DATE
# 5: CARDINAL
# 17: CARDINAL
# 9: CARDINAL
# 12: CARDINAL
# 12: CARDINAL
# 11: CARDINAL
# 10: CARDINAL
# 4: CARDINAL
# 4: CARDINAL
# 252: CARDINAL
# 865: CARDINAL
# 13: CARDINAL
# third quarter first nine months 2017: DATE
# 2016: DATE
# first quarter 2017: DATE
# mac: ORG
# third quarter first nine months 2017: DATE
# 2016 apple inc q3 2017: DATE
# 10: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017: DATE
# 25 2016: DATE
# july 1 2017june 25 2016: DATE
# 7: CARDINAL
# 5: CARDINAL
# 22: CARDINAL
# 21: CARDINAL
# 479: CARDINAL
# 18 023: DATE
# 19: CARDINAL
# 16: CARDINAL
# 12 11: CARDINAL
# third quarter first nine months 2017: DATE
# 2016: DATE
# china: GPE
# japan: GPE
# asia pacific americas: LOC
# north south america europe: LOC
# european: NORP
# india: GPE
# middle east africa: LOC
# china: GPE
# hong kong: GPE
# taiwan: GPE
# asia pacific: LOC
# asian: NORP
# one: CARDINAL
# 1: CARDINAL
# 11: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017: DATE
# 25 2016: DATE
# july 1 2017june 25 2016: DATE
# 20: CARDINAL
# 17: CARDINAL
# 963: CARDINAL
# 73: CARDINAL
# 501: CARDINAL
# 66: CARDINAL
# 384: CARDINAL
# 11: CARDINAL
# 45: CARDINAL
# 42: CARDINAL
# 42: DATE
# 39: CARDINAL
# third quarter 2017: DATE
# 2016: DATE
# year year: DATE
# first nine months 2017: DATE
# europe: LOC
# europe: LOC
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1: DATE
# july 1 2017: DATE
# 25 2016: DATE
# 10: CARDINAL
# 9: CARDINAL
# 643: CARDINAL
# 41: CARDINAL
# 929: CARDINAL
# 39: CARDINAL
# 24: CARDINAL
# 24: CARDINAL
# europe: LOC
# third quarter first nine months 2017: DATE
# 2016: DATE
# europe: LOC
# third quarter first nine months 2017: DATE
# 2016 apple inc q3 2017: DATE
# 10: CARDINAL
# china: GPE
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017: DATE
# 25 2016: DATE
# july 1 2017: DATE
# 25 2016: DATE
# 8: CARDINAL
# 848: CARDINAL
# 39: CARDINAL
# 12: CARDINAL
# 18: CARDINAL
# 24: CARDINAL
# china: GPE
# third quarter first nine months 2017: DATE
# 2016: DATE
# third quarter first nine months 2017: DATE
# 2016: CARDINAL
# japan: GPE
# japan: GPE
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017: DATE
# 25 2016: DATE
# july 1 2017: DATE
# 25 2016: DATE
# 3: CARDINAL
# 529: CARDINAL
# 3: CARDINAL
# 13: CARDINAL
# 875: CARDINAL
# 12: CARDINAL
# 604: CARDINAL
# 8: CARDINAL
# japan: GPE
# third: ORDINAL
# 2017: DATE
# 2016: DATE
# year year: DATE
# japan: GPE
# first nine months 2017: DATE
# japanese: NORP
# japan: GPE
# first nine months 2017: DATE
# 2016: DATE
# asia pacific: LOC
# asia pacific: LOC
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1: DATE
# july 1 2017: DATE
# 25 2016: DATE
# 2: CARDINAL
# 2: CARDINAL
# 12: CARDINAL
# 10: CARDINAL
# 982: CARDINAL
# 13: CARDINAL
# 6: CARDINAL
# asia pacific: LOC
# third quarter first nine months 2017: DATE
# 2016: DATE
# asia pacific: LOC
# third quarter first nine months 2017: DATE
# 2016 apple inc q3 2017: DATE
# 10: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017 june 25: DATE
# 1 2017 june 25 2016: DATE
# 45: CARDINAL
# 408: CARDINAL
# 42: CARDINAL
# 358: CARDINAL
# 176: CARDINAL
# 655: CARDINAL
# 168: CARDINAL
# 787: PRODUCT
# 27: CARDINAL
# 26: CARDINAL
# 108: CARDINAL
# 400: CARDINAL
# 102: CARDINAL
# 17: CARDINAL
# 16 106: DATE
# 68: CARDINAL
# 255: CARDINAL
# 66 450: CARDINAL
# 38: CARDINAL
# 38: CARDINAL
# 4: CARDINAL
# third quarter 2017: DATE
# quarter 2016: DATE
# year year: DATE
# months 2017: DATE
# third quarter first nine months 2017: DATE
# 2016: DATE
# fourth quarter 2017: DATE
# 38: CARDINAL
# fourth quarter 2017: DATE
# 1a: CARDINAL
# 10: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017 june 25: DATE
# 1 2017 june 25 2016: DATE
# 2: CARDINAL
# 937: CARDINAL
# 2: CARDINAL
# 7 475 percentage total: PERCENT
# 6: CARDINAL
# 3: CARDINAL
# 447: CARDINAL
# 10: CARDINAL
# 712: CARDINAL
# 8 8 6 6: CARDINAL
# 6: CARDINAL
# 6: CARDINAL
# 20: CARDINAL
# 18 187: CARDINAL
# 15: CARDINAL
# 11 11: CARDINAL
# third quarter first nine months 2017: DATE
# 2016: CARDINAL
# third quarter first nine months 2017: DATE
# 2016: CARDINAL
# apple inc q3 2017: ORG
# 10 q: TIME
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017: DATE
# 1 2017june 25 2016: DATE
# 1: CARDINAL
# 833: CARDINAL
# 963: CARDINAL
# 602: CARDINAL
# 409: CARDINAL
# 1: CARDINAL
# 1 006: CARDINAL
# 185 263: CARDINAL
# 228: CARDINAL
# 1 036: CARDINAL
# 540: CARDINAL
# 364: CARDINAL
# 48: CARDINAL
# 1: CARDINAL
# 112: CARDINAL
# third quarter first nine months 2017: DATE
# 2016: DATE
# 77 third quarter 2017 2016: DATE
# 1: CARDINAL
# three nine month: DATE
# july 1 2017: DATE
# three months ended nine months ended july 1 2017 june 25: DATE
# 1 2017 june 25 2016: DATE
# 2: CARDINAL
# 12: CARDINAL
# 535: CARDINAL
# 12: CARDINAL
# 511: CARDINAL
# 22: CARDINAL
# 25: CARDINAL
# 25 4: CARDINAL
# third quarter first nine months 2017: DATE
# 35: CARDINAL
# third quarter first nine months 2017: DATE
# 2016: DATE
# irs: ORG
# years 2010: DATE
# 2012: DATE
# irs: ORG
# years 2010 2012 third quarter 2017 years prior 2013: DATE
# irs: ORG
# years 2013 2015: DATE
# august 30 2016: DATE
# european commission: ORG
# 1991: DATE
# irish: NORP
# two: CARDINAL
# june 2003: DATE
# december 2014: DATE
# irish: NORP
# january 2015: DATE
# general court court: ORG
# union ireland: PERSON
# european commission: ORG
# 13 billion: CARDINAL
# european: NORP
# irish: NORP
# 2017: DATE
# 10: CARDINAL
# 28recent: CARDINAL
# november 2016: DATE
# 2016 18: DATE
# 230: CARDINAL
# 2016 18: DATE
# 2016 18 first quarter 2019: DATE
# october 2016: DATE
# 2016 16: DATE
# 740: CARDINAL
# 2016 16: DATE
# 2016 16 first quarter 2019: DATE
# 9 billion: CARDINAL
# 2016 16: DATE
# march 2016: DATE
# 2016 09: DATE
# 718: CARDINAL
# 2016 09: DATE
# 2016 09 first quarter 2018: DATE
# february 2016: DATE
# 2016 02: DATE
# 842: CARDINAL
# 2016 02: DATE
# 2016 02: DATE
# first quarter 2020: DATE
# 2016 02: DATE
# 8 5 billion: MONEY
# 2016 02: DATE
# january 2016: DATE
# 2016 01: DATE
# 825 10: CARDINAL
# 2016 01: DATE
# 2016 01 first quarter 2019: DATE
# 2016 01: DATE
# june 2016: DATE
# 2016 13: DATE
# 326: CARDINAL
# 2016 13: DATE
# 2016 13 first quarter 2021: DATE
# 2016 13: DATE
# 2014: DATE
# 2014 09: DATE
# 606: CARDINAL
# 2014 09: DATE
# 2014 09: DATE
# apple inc q3 2017: ORG
# 10: CARDINAL
# 2014: CARDINAL
# 2016 08: DATE
# 606: CARDINAL
# 2016 08: DATE
# 2016 10: DATE
# 606: CARDINAL
# 2016 10: DATE
# 2016 12: DATE
# 606: CARDINAL
# 2016 12: DATE
# 2016 20: DATE
# 606: CARDINAL
# 2016 20: CARDINAL
# 2016 08: DATE
# 2016 10: DATE
# 2016 12: DATE
# 2016 20: DATE
# 2014 09: DATE
# first quarter 2019: DATE
# july 1 2017: DATE
# 24 2016 first nine months 2017: DATE
# july 1 2017: DATE
# 24 2016: TIME
# 261 516: CARDINAL
# 585: CARDINAL
# 29: CARDINAL
# 286: CARDINAL
# 27: CARDINAL
# 010: CARDINAL
# 11: CARDINAL
# 980: CARDINAL
# 8 105: CARDINAL
# 96: CARDINAL
# 359: CARDINAL
# 78 927: CARDINAL
# 31: CARDINAL
# 27: CARDINAL
# 863 nine months ended july 1: DATE
# 47: CARDINAL
# 942: CARDINAL
# 49: CARDINAL
# 698: CARDINAL
# 36: CARDINAL
# 504: CARDINAL
# 38 580: CARDINAL
# 13: CARDINAL
# 14 001: CARDINAL
# next 12 months: DATE
# july 1 2017: DATE
# 24 2016: DATE
# 246: CARDINAL
# 216 0 billion: MONEY
# european commission: ORG
# 13 billion: CARDINAL
# european: NORP
# one: CARDINAL
# nine months ended july 1 2017: DATE
# 47 9 billion: MONEY
# 37 6 billion: QUANTITY
# 16 0 billion: QUANTITY
# 5 7 billion: MONEY
# one: CARDINAL
# 1 9 billion: MONEY
# year: DATE
# 36 5 billion nine months ended july 1 2017: MONEY
# 27 7 billion: MONEY
# 8 6 billion: QUANTITY
# 13 4 billion nine months ended july 1 2017: MONEY
# 25 1 billion: QUANTITY
# 9 5 billion: QUANTITY
# 3 5 billion: MONEY
# 21 7 billion: MONEY
# 3 9 billion apple inc q3: MONEY
# 2017: DATE
# 10 q 30during nine months ended june 25 2016: TIME
# 49 7 billion: MONEY
# 36: CARDINAL
# 7 billion: CARDINAL
# 16 7 billion: MONEY
# 3 7 billion: MONEY
# 38 6 billion nine months ended june 25 2016: MONEY
# 27 2 billion: QUANTITY
# 8 8 billion: MONEY
# 14 0 billion nine months ended june 25 2016: MONEY
# 7 billion: CARDINAL
# 9 1 billion: QUANTITY
# 2 5 billion: MONEY
# 18 0 billion: QUANTITY
# 4 0 billion: MONEY
# 8 5 billion first nine months 2017: MONEY
# approximately 15 0 billion: QUANTITY
# 2017: DATE
# july 1 2017: DATE
# 12: CARDINAL
# 1 01: QUANTITY
# less nine months july 1 2017: DATE
# 96 6 billion: QUANTITY
# third quarter 2017: DATE
# 3 5 billion: MONEY
# 1: CARDINAL
# 2: CARDINAL
# 6: CARDINAL
# 2017: DATE
# 250 billion 300 billion: MONEY
# 175 billion 210 billion: MONEY
# quarterly: DATE
# 0: CARDINAL
# 57: CARDINAL
# 0 63: CARDINAL
# third quarter 2017: DATE
# annual: DATE
# july 1: DATE
# 158 billion: MONEY
# 10b5 1 exchange: MONEY
# august 2012: DATE
# 1 2017 millions: MONEY
# 2017: DATE
# 3: CARDINAL
# 11: CARDINAL
# 723: MONEY
# 2017 3: DATE
# 4: CARDINAL
# 159: CARDINAL
# 10: CARDINAL
# 164: CARDINAL
# 5: DATE
# 629: CARDINAL
# 14: CARDINAL
# 12: CARDINAL
# 17: CARDINAL
# 1: CARDINAL
# 42: CARDINAL
# 2015: DATE
# 11: CARDINAL
# 6: DATE
# 30: CARDINAL
# 026: CARDINAL
# 49: CARDINAL
# 2014: DATE
# 126: CARDINAL
# 21: DATE
# 24: CARDINAL
# 1: CARDINAL
# 158: CARDINAL
# 284: CARDINAL
# 2013: DATE
# 10: CARDINAL
# 564: CARDINAL
# 13: CARDINAL
# 34: CARDINAL
# 2012: DATE
# 2: DATE
# 488: CARDINAL
# 56: CARDINAL
# 2 544: CARDINAL
# 57: CARDINAL
# 388: CARDINAL
# 64: CARDINAL
# 950: CARDINAL
# 527: CARDINAL
# 7: CARDINAL
# 011: CARDINAL
# 222: CARDINAL
# 876: CARDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# march 2019: DATE
# july 1 2017: DATE
# 8 5 billion: MONEY
# 10 years: DATE
# multi year: DATE
# 150 days: DATE
# july 1 2017: DATE
# 23 4 billion: MONEY
# july 1 2017: DATE
# 9 0 billion: MONEY
# july 1 2017: DATE
# 30 2 billion: QUANTITY
# 8 6 billion: MONEY
# third: ORDINAL
# third: ORDINAL
# k: GPE
# china: GPE
# 2017: DATE
# 10: CARDINAL
# 1: CARDINAL
# 1: CARDINAL
# 8 2016: DATE
# 10: CARDINAL
# 7 2016: DATE
# 10: CARDINAL
# 2016: DATE
# 10: CARDINAL
# 3: CARDINAL
# first nine months 2017: DATE
# 7a: CARDINAL
# 2016: CARDINAL
# 10: CARDINAL
# 4: CARDINAL
# 13a 15 e 15d 15: DATE
# july 1 2017: DATE
# sec: ORG
# third quarter 2017: DATE
# 13a 15 15d 15: DATE
# 2017: DATE
# 10 q 33part: TIME
# informa: NORP
# 1: CARDINAL
# one: CARDINAL
# 1a: CARDINAL
# 10: CARDINAL
# third quarter 2017: DATE
# 1a: CARDINAL
# 1a 2016: CARDINAL
# 10: CARDINAL
# 1a: CARDINAL
# 10 q quarters ended december 31 2016: DATE
# 1 2017: DATE
# 10: CARDINAL
# 1: CARDINAL
# 2: CARDINAL
# 10: CARDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# third: ORDINAL
# third: ORDINAL
# 2017: DATE
# 10: CARDINAL
# third: ORDINAL
# 150 days: DATE
# suf: NORP
# one: CARDINAL
# manuf: ORG
# 2017: DATE
# 10: CARDINAL
# asia: LOC
# asia europe: LOC
# asia: LOC
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# 2017: DATE
# 10: CARDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# one: CARDINAL
# third: ORDINAL
# one: CARDINAL
# one: CARDINAL
# one: CARDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# third: ORDINAL
# third: ORDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# third: ORDINAL
# 2017: DATE
# 10: CARDINAL
# quarterly: DATE
# first quarter: DATE
# quarters: CARDINAL
# seasonal: DATE
# quarterly: DATE
# late quarter: DATE
# apple inc q3 2017: ORG
# 10: CARDINAL
# third: ORDINAL
# third: ORDINAL
# july 1 2017: DATE
# asia: LOC
# irs: ORG
# 2017: DATE
# 10: CARDINAL
# 2: CARDINAL
# three months ended july 1 2017: DATE
# millions: CARDINAL
# thousands: CARDINAL
# 1 april 2 2017: DATE
# 6 2017: DATE
# 6: CARDINAL
# 968: CARDINAL
# 143: CARDINAL
# 968: CARDINAL
# 7 2017 june 3 2017: DATE
# february 2017: DATE
# 3: CARDINAL
# 2017: DATE
# 15: CARDINAL
# 10: CARDINAL
# 1 2017: DATE
# 12: CARDINAL
# 738: CARDINAL
# 146: CARDINAL
# 31: CARDINAL
# 12 738: CARDINAL
# 49: CARDINAL
# 376: CARDINAL
# 51: CARDINAL
# may 2017: DATE
# 175 billion 210 billion: MONEY
# 158 billion: MONEY
# july 1 2017: DATE
# 52 billion: CARDINAL
# july 1 2017: DATE
# 10b5 1 exchange: MONEY
# 2: CARDINAL
# february 2017: DATE
# 3 0 billion: MONEY
# 2017: DATE
# 4 million: CARDINAL
# 20 9 million: CARDINAL
# 143: CARDINAL
# 20: CARDINAL
# 3 0 billion: MONEY
# 3 0 billion: MONEY
# august 2017: DATE
# 3: CARDINAL
# 4: CARDINAL
# 5: CARDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# 6: CARDINAL
# 4 1: CARDINAL
# 11 2017: DATE
# 2020: DATE
# 2022 1 800: DATE
# 2020 2 300: DATE
# 2022 2 850: DATE
# 2024: CARDINAL
# 3: CARDINAL
# 200: CARDINAL
# 2027 8: DATE
# 4: CARDINAL
# 17: CARDINAL
# 2: CARDINAL
# 24 2017: DATE
# 0 875: CARDINAL
# 2025 1 375: DATE
# 2029 8: DATE
# 4: CARDINAL
# 3: CARDINAL
# june 20 2017: DATE
# 3 000: CARDINAL
# 2027 8: DATE
# 17: CARDINAL
# 13a 14 15d: DATE
# 31: CARDINAL
# 13a 14 15d: DATE
# 32 1: CARDINAL
# 1350: DATE
# 101: CARDINAL
# 101: CARDINAL
# 101: CARDINAL
# 101: CARDINAL
# 101: CARDINAL
# apple inc q3 2017: ORG
# 10: CARDINAL
# 1934: DATE
# august 2 2017: DATE
# apple inc luca: ORG
# 2017: DATE
# 10: CARDINAL
# 46 10: DATE
# 1: CARDINAL
# k20189292018: NORP
# 10: CARDINAL
# united states securities exchange commission: ORG
# washington: ORG
# 20549: DATE
# 10 k mark one: QUANTITY
# annual: DATE
# 13: CARDINAL
# 1934 fiscal year ended september 29 2018: DATE
# 13: CARDINAL
# 1934: DATE
# apple inc exact: ORG
# california: GPE
# 94 2404110: DATE
# one: CARDINAL
# apple park w ay cupertino california 95014: FAC
# 408: CARDINAL
# 996 1010: DATE
# section 12: LAW
# 00001: DATE
# 1 000: CARDINAL
# 2022 1 375: DATE
# 2024: CARDINAL
# 0: CARDINAL
# 875: CARDINAL
# 2025 1: DATE
# 625: CARDINAL
# 2026 2: DATE
# 2027 1 375: CARDINAL
# 2029 3: DATE
# 2029: CARDINAL
# 3: CARDINAL
# 600: CARDINAL
# new york stock exchange: ORG
# new york stock exchange: ORG
# new york stock exchange: ORG
# new york stock exchange: ORG
# new york stock exchange: ORG
# new york stock exchange: ORG
# new york stock exchange: ORG
# new york stock exchange: ORG
# section 12: LAW
# 405: CARDINAL
# 13: CARDINAL
# section 15: LAW
# 1: CARDINAL
# 13: CARDINAL
# 1934: DATE
# 12 months: DATE
# 2: CARDINAL
# past 90 days: DATE
# 405: CARDINAL
# 232 405: CARDINAL
# 12 months: DATE
# 405: CARDINAL
# 229: CARDINAL
# 10 k amendment form: QUANTITY
# 10: CARDINAL
# filer: ORG
# 12b 2: DATE
# section 13: LAW
# 12b 2: DATE
# march 30 2018: DATE
# second fiscal quarter approximately 828: DATE
# 880 000: CARDINAL
# 000: CARDINAL
# 4: CARDINAL
# 398 000: CARDINAL
# october 26 2018: DATE
# 2019: DATE
# annual: DATE
# 2019: DATE
# annual: DATE
# 10: CARDINAL
# 2019: DATE
# u securities exchange commission: ORG
# 120 days end fiscal year: DATE
# apple inc: ORG
# 10 k fiscal year ended september 29 2018: DATE
# 1: CARDINAL
# 1: CARDINAL
# 1a: CARDINAL
# 8: CARDINAL
# 1b: CARDINAL
# 17: CARDINAL
# 2: CARDINAL
# 18: CARDINAL
# 3: CARDINAL
# 18: CARDINAL
# 4: CARDINAL
# 18: CARDINAL
# 5: CARDINAL
# 19: CARDINAL
# 6: CARDINAL
# 21: CARDINAL
# 7: CARDINAL
# 22: CARDINAL
# 7a: CARDINAL
# 35: CARDINAL
# 8: CARDINAL
# 37: CARDINAL
# 9: CARDINAL
# 67: CARDINAL
# 9a: CARDINAL
# 67: CARDINAL
# 9b: CARDINAL
# 67: CARDINAL
# 10: CARDINAL
# 68: CARDINAL
# 11: CARDINAL
# 68: CARDINAL
# 12: CARDINAL
# 68: CARDINAL
# 13: CARDINAL
# 68: CARDINAL
# 14: CARDINAL
# 68: CARDINAL
# 15: CARDINAL
# 69: CARDINAL
# 16: CARDINAL
# 71: CARDINAL
# annual: DATE
# 10: CARDINAL
# 10: CARDINAL
# 1995: DATE
# 7: CARDINAL
# 10: CARDINAL
# 1a: CARDINAL
# 10: CARDINAL
# particular years quarters months: DATE
# fiscal years ended september: DATE
# quarters months: DATE
# fiscal years: DATE
# apple inc wholly: ORG
# 1: CARDINAL
# third: ORDINAL
# mac apple: PERSON
# third: ORDINAL
# third: ORDINAL
# fiscal year: DATE
# 53 week: DATE
# last saturday: DATE
# september: DATE
# california: GPE
# 1977: DATE
# mac windows: PERSON
# third: ORDINAL
# third: ORDINAL
# september 2018: DATE
# three: CARDINAL
# max: PERSON
# september 2018: DATE
# retina lcd: PERSON
# october 2018: DATE
# 8 8 plus: CARDINAL
# apps apple inc 2018: ORG
# 10: CARDINAL
# touch id march 2018: DATE
# 9 7 inch: QUANTITY
# apple pencil compatibility: ORG
# october 2018: DATE
# 11 inch: QUANTITY
# 12 9 inch: QUANTITY
# retina lcd: PERSON
# apps mac mac: PERSON
# 21 5 inch: QUANTITY
# 21 5 inch: QUANTITY
# 27 inch: QUANTITY
# october 2018: DATE
# mac mini: PERSON
# september 2018: DATE
# 12: CARDINAL
# third: ORDINAL
# apps macos macos: PERSON
# macos: PERSON
# september 2018: DATE
# apps news: ORG
# first: ORDINAL
# macos: PERSON
# september 2018: DATE
# 5: CARDINAL
# w alkie alkie: PERSON
# third: ORDINAL
# apps siri: PERSON
# september 2018: DATE
# 12: CARDINAL
# mac: PERSON
# apple inc 2018: ORG
# 10: CARDINAL
# mac: PERSON
# participatin g apps: PERSON
# december 2017: DATE
# 11: CARDINAL
# 4: CARDINAL
# apps built television: ORG
# 4k: CARDINAL
# 4k: CARDINAL
# crown: ORG
# apps apple: PERSON
# september 2018: DATE
# apple w atch series: ORG
# 4: CARDINAL
# apple branded third party: ORG
# february 2018: DATE
# fidelity: ORG
# apps: PERSON
# creating apps: PERSON
# debug apps: PERSON
# apple inc 2018: ORG
# 10: CARDINAL
# 3: CARDINAL
# third: ORDINAL
# third: ORDINAL
# 2018: DATE
# 29 71: CARDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# thousands third: CARDINAL
# 10: CARDINAL
# 2018 2017: DATE
# 2016: DATE
# third: ORDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# third: ORDINAL
# mac apple: PERSON
# one: CARDINAL
# asia mac: LOC
# u ireland: GPE
# 150 days: DATE
# third: ORDINAL
# 2018: DATE
# 10: CARDINAL
# 5: CARDINAL
# thousands: CARDINAL
# third: ORDINAL
# third: ORDINAL
# 2018: DATE
# 37 63: CARDINAL
# first quarter: DATE
# quarters fiscal year: DATE
# seasonal: DATE
# one year date: DATE
# 90 day: DATE
# two years: DATE
# september 29 2018: DATE
# approximately 132: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 6: CARDINAL
# annual: DATE
# 10: CARDINAL
# quarterly: DATE
# 10: CARDINAL
# 8: CARDINAL
# 13: CARDINAL
# 1934: CARDINAL
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# sec: ORG
# annual: DATE
# 10: CARDINAL
# 2018: DATE
# 10: CARDINAL
# 7: CARDINAL
# 1a: CARDINAL
# 10: CARDINAL
# 7: CARDINAL
# 8: CARDINAL
# 10: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 8: CARDINAL
# third: ORDINAL
# third: ORDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 9: CARDINAL
# 150 days: DATE
# suf: NORP
# one: CARDINAL
# manuf: ORG
# suf: NORP
# suf ficient quantities: ORG
# asia: LOC
# ng: ORG
# asia europe: LOC
# asia: LOC
# apple inc 2018: ORG
# 10: CARDINAL
# 10: CARDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# 2018: DATE
# 10: CARDINAL
# 11: CARDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# 8: CARDINAL
# 9: CARDINAL
# one: CARDINAL
# third: ORDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 12: CARDINAL
# one: CARDINAL
# one: CARDINAL
# one: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 13: CARDINAL
# third: ORDINAL
# third: ORDINAL
# third: ORDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 14: CARDINAL
# third: ORDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 15: CARDINAL
# quarterly: DATE
# first quarter: DATE
# quarters: CARDINAL
# seasonal: DATE
# quarterly: DATE
# one: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 16: CARDINAL
# third: ORDINAL
# third: ORDINAL
# september 29 2018: DATE
# asia: LOC
# irs: ORG
# 1b: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 17: CARDINAL
# 2: CARDINAL
# cupertino: GPE
# california: GPE
# 29 2018: DATE
# 16 5 million square feet: QUANTITY
# 24 3 million square feet: QUANTITY
# 7 376 acres: QUANTITY
# september 29 2018: DATE
# 3: CARDINAL
# 8: CARDINAL
# 9: CARDINAL
# one: CARDINAL
# 1a: CARDINAL
# 10: CARDINAL
# fourth quarter 2018: DATE
# 4: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 18: CARDINAL
# 5: CARDINAL
# october 26 2018: DATE
# 23: CARDINAL
# 712: CARDINAL
# three months ended september 29 2018: DATE
# millions: CARDINAL
# thousands: CARDINAL
# 1 july 1 2018: DATE
# 4 2018: DATE
# 26: CARDINAL
# 859: CARDINAL
# 192: CARDINAL
# 50: DATE
# august 5 2018: DATE
# 1 2018: DATE
# 36: CARDINAL
# 575: CARDINAL
# 214: CARDINAL
# 07: CARDINAL
# 2 2018: DATE
# 29 2018: DATE
# 29: CARDINAL
# 222: CARDINAL
# 07 29: DATE
# 029: PRODUCT
# 92 463: CARDINAL
# 100 billion: MONEY
# 29 0 billion: MONEY
# september 29 2018: DATE
# 71 0 billion: MONEY
# 29 2018: DATE
# 10b5 1 exchange act apple inc 2018: MONEY
# 10: CARDINAL
# 19: CARDINAL
# 500: CARDINAL
# five years ended september 29 2018: DATE
# 100: CARDINAL
# 500: CARDINAL
# september 27 2013: DATE
# jpg 100: PERSON
# september 27 2013: DATE
# last day fiscal year: DATE
# september 30th: DATE
# 2018: DATE
# 2018: DATE
# dow jones indices llc division p global rights reserved: ORG
# 2016september 2017 september 2018: DATE
# apple inc: ORG
# 100: CARDINAL
# 242: CARDINAL
# 359: CARDINAL
# 500: CARDINAL
# 100: CARDINAL
# 120: CARDINAL
# 137: CARDINAL
# 163: CARDINAL
# 192: CARDINAL
# 100: CARDINAL
# 129: CARDINAL
# 132: CARDINAL
# 162: CARDINAL
# 275: CARDINAL
# 100: CARDINAL
# 159: CARDINAL
# 203: CARDINAL
# 266: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 20: CARDINAL
# 6: CARDINAL
# five years ended september 29 2018: DATE
# 7: CARDINAL
# 8: CARDINAL
# 10: CARDINAL
# millions: CARDINAL
# thousands: CARDINAL
# 2018 2017 2016 2015 2014: DATE
# 265: CARDINAL
# 595: CARDINAL
# 229: CARDINAL
# 234: CARDINAL
# 215: CARDINAL
# 639: CARDINAL
# 233: CARDINAL
# 715: CARDINAL
# 182 795: CARDINAL
# 59: CARDINAL
# 531: CARDINAL
# 48: CARDINAL
# 351: CARDINAL
# 45: CARDINAL
# 687: CARDINAL
# 394: CARDINAL
# 39: CARDINAL
# 510: CARDINAL
# 12 01: DATE
# 11: CARDINAL
# 91: CARDINAL
# 9: DATE
# 22: CARDINAL
# 6 45: CARDINAL
# 2 72: DATE
# 4: CARDINAL
# 217: CARDINAL
# 242: CARDINAL
# 5: CARDINAL
# 820: CARDINAL
# 5: CARDINAL
# 753: CARDINAL
# 6: CARDINAL
# 572: CARDINAL
# 5: CARDINAL
# 109: CARDINAL
# 5: CARDINAL
# 251: CARDINAL
# 692: CARDINAL
# 5: CARDINAL
# 793: CARDINAL
# 069: CARDINAL
# 6: CARDINAL
# 122 663: CARDINAL
# 237 100: CARDINAL
# 895: CARDINAL
# 585: CARDINAL
# 205: CARDINAL
# 666: CARDINAL
# 155: CARDINAL
# 725: CARDINAL
# 375: CARDINAL
# 686: CARDINAL
# 290: CARDINAL
# 345: CARDINAL
# 839: CARDINAL
# 93: CARDINAL
# 735: CARDINAL
# 97: CARDINAL
# 207: CARDINAL
# 75: DATE
# 53: CARDINAL
# 329: CARDINAL
# 28: CARDINAL
# 987: CARDINAL
# 45: CARDINAL
# 415: CARDINAL
# 36: CARDINAL
# 074: CARDINAL
# 33: CARDINAL
# 24: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 21: CARDINAL
# 7: CARDINAL
# annual: DATE
# 10: CARDINAL
# 10: CARDINAL
# 1995: DATE
# 1a: CARDINAL
# 10: CARDINAL
# 8: CARDINAL
# 10: CARDINAL
# particular years quarters months: DATE
# fiscal years ended september: DATE
# quarters months: DATE
# fiscal years: DATE
# apple inc wholly: ORG
# third: ORDINAL
# mac apple: PERSON
# third: ORDINAL
# third: ORDINAL
# 53 week: DATE
# last saturday: DATE
# september company fiscal years 2018 2016: DATE
# 52 weeks: DATE
# fiscal year 2017: DATE
# 53 weeks 14th week: DATE
# first quarter 2017: DATE
# every five six years: DATE
# fiscal quarters calendar quarters fiscal 2018: DATE
# 16: CARDINAL
# 36 4 billion 2018: MONEY
# 2017: DATE
# year year: DATE
# may 2018: DATE
# 100 billion: MONEY
# quarterly: DATE
# 0: CARDINAL
# 63: CARDINAL
# 0 73: CARDINAL
# 2018 2018: DATE
# 73 1 billion: QUANTITY
# 13 7 billion: MONEY
# fiscal 2017: DATE
# 6 13 6 billion 2017: MONEY
# 2016: DATE
# year year: DATE
# 2017: DATE
# 2017: DATE
# 250 billion 300 billion: MONEY
# 175 billion 210 billion: MONEY
# quarterly: DATE
# 0: CARDINAL
# 57: CARDINAL
# 0 63: CARDINAL
# 2017: DATE
# 33 0 billion: QUANTITY
# 12 8 billion 210 billion: MONEY
# third quarter 2018: DATE
# 24 0 billion: MONEY
# 2 5 billion euro: QUANTITY
# 2 5 billion canadian dollar: MONEY
# 2017: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# 22: CARDINAL
# 2018 2017 2016 dollars: DATE
# millions: CARDINAL
# thousands 2018: DATE
# 2017: DATE
# 2016: DATE
# 112: CARDINAL
# 16 96: CARDINAL
# 600: CARDINAL
# 86: CARDINAL
# 62 420: DATE
# 14 54: DATE
# 938: CARDINAL
# 10: CARDINAL
# 49: DATE
# 952: CARDINAL
# 51: CARDINAL
# 16 44: DATE
# 8: CARDINAL
# japan: GPE
# 21: CARDINAL
# 23: CARDINAL
# 17: CARDINAL
# 5: CARDINAL
# 16: CARDINAL
# asia pacific: LOC
# 17 407: CARDINAL
# 15: CARDINAL
# 15: CARDINAL
# 199: CARDINAL
# 11: CARDINAL
# 13 654: CARDINAL
# 265: CARDINAL
# 595: CARDINAL
# 229: CARDINAL
# 6: CARDINAL
# 215 639: CARDINAL
# 1: CARDINAL
# 699: CARDINAL
# 18: CARDINAL
# 319: CARDINAL
# 136 700: CARDINAL
# 1 18: DATE
# 19: DATE
# 7: CARDINAL
# 20: CARDINAL
# 1: CARDINAL
# 13: CARDINAL
# 22: CARDINAL
# 831: CARDINAL
# 2 37: DATE
# 24 29: DATE
# 23: CARDINAL
# 24 348: CARDINAL
# 1 3: DATE
# 35 12: DATE
# 863: CARDINAL
# 16: CARDINAL
# 11 132: CARDINAL
# 265: CARDINAL
# 595: CARDINAL
# 229: CARDINAL
# 6: CARDINAL
# 215: CARDINAL
# 639: CARDINAL
# 217: CARDINAL
# 216: CARDINAL
# 756: CARDINAL
# 2: CARDINAL
# 884: CARDINAL
# 43: CARDINAL
# 43: CARDINAL
# 753: CARDINAL
# 4: CARDINAL
# 45 590: CARDINAL
# 18: CARDINAL
# 209: CARDINAL
# 5: CARDINAL
# 18: CARDINAL
# 2: CARDINAL
# 2018: DATE
# one: CARDINAL
# 236 million: CARDINAL
# 2017: DATE
# one: CARDINAL
# 640 million: CARDINAL
# 3: CARDINAL
# apple branded third party: ORG
# apple inc 2018: ORG
# 10: CARDINAL
# 23: CARDINAL
# 2018 2017 2016 dollars: DATE
# millions: CARDINAL
# thousands 2018: DATE
# 2017: DATE
# 2016: DATE
# 166: CARDINAL
# 699: CARDINAL
# 18: CARDINAL
# 319: CARDINAL
# 136: CARDINAL
# 63: CARDINAL
# 62: CARDINAL
# 63: CARDINAL
# 217: CARDINAL
# 216: CARDINAL
# 756: CARDINAL
# 2: CARDINAL
# 211: CARDINAL
# 884: CARDINAL
# 2018: DATE
# 2017: DATE
# 2017: DATE
# 2016: DATE
# 2017: DATE
# 2018 2017 2016 dollars: DATE
# millions: CARDINAL
# thousands 2018: DATE
# 2017: DATE
# 2016: DATE
# 18: CARDINAL
# 19: DATE
# 7: CARDINAL
# 20: CARDINAL
# 628: CARDINAL
# 7: CARDINAL
# 8 10: QUANTITY
# 43: CARDINAL
# 535: CARDINAL
# 43: CARDINAL
# 753: CARDINAL
# 4: CARDINAL
# 45 590: CARDINAL
# 2018: DATE
# 2017: DATE
# 2018: DATE
# 2017: DATE
# 2016: DATE
# 2017: DATE
# 2018 2017 2016 dollars: DATE
# millions: CARDINAL
# thousands 2018: DATE
# 2017: DATE
# 2016: DATE
# 25: CARDINAL
# 13: CARDINAL
# 22: CARDINAL
# 831: CARDINAL
# 10: CARDINAL
# 11 11: CARDINAL
# 18: CARDINAL
# 209: CARDINAL
# 5: CARDINAL
# 4: CARDINAL
# mac: PERSON
# 2018: DATE
# 2017: DATE
# 2018: DATE
# 2017: DATE
# 2016: DATE
# mac: ORG
# 2017 apple inc 2018: DATE
# 10: CARDINAL
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2017: DATE
# 2016: DATE
# 37: CARDINAL
# 24 29: DATE
# 23: CARDINAL
# 24: CARDINAL
# 348: CARDINAL
# 14 13 11 year year: DATE
# 2018: DATE
# 2018: DATE
# one: CARDINAL
# 236 million: CARDINAL
# year year: DATE
# 2017: DATE
# 2017: DATE
# one: CARDINAL
# 640 million: CARDINAL
# china: GPE
# japan: GPE
# asia pacific americas: LOC
# north south america europe: LOC
# european: NORP
# india: GPE
# middle east africa: LOC
# china: GPE
# hong kong: GPE
# taiwan: GPE
# asia pacific: LOC
# asian: NORP
# one: CARDINAL
# 8: CARDINAL
# 10: CARDINAL
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2017: DATE
# 2016: DATE
# 112: CARDINAL
# 16 96: CARDINAL
# 600: CARDINAL
# 42: CARDINAL
# 2018: DATE
# 2017: DATE
# 2017: DATE
# 2016: DATE
# europe: LOC
# europe: LOC
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2017: DATE
# 2016: DATE
# 62: CARDINAL
# 14 54: DATE
# 938: CARDINAL
# 10: CARDINAL
# 952: CARDINAL
# 24: CARDINAL
# 24: CARDINAL
# 23: CARDINAL
# europe: LOC
# 2018: DATE
# 2017: DATE
# europe: LOC
# 2018: DATE
# europe: LOC
# 2017: DATE
# 2016: DATE
# europe: LOC
# 2017: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# china: GPE
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2017: DATE
# 2016: DATE
# 51: CARDINAL
# 942: CARDINAL
# 16 44: DATE
# 764: CARDINAL
# 20: CARDINAL
# china: GPE
# 2018: DATE
# 2017: DATE
# 2018: DATE
# china: GPE
# 2017: DATE
# 2016: DATE
# 2017: DATE
# japan: GPE
# japan: GPE
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2017: DATE
# 2016: DATE
# 21: CARDINAL
# 23: CARDINAL
# 17: CARDINAL
# 5: CARDINAL
# 16 928 percentage total: PERCENT
# 8: CARDINAL
# japan: GPE
# 2018: DATE
# 2017: DATE
# year year: DATE
# japan: GPE
# 2017: DATE
# japanese: NORP
# asia pacific: LOC
# asia pacific: LOC
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2017: DATE
# 2016: DATE
# 17: CARDINAL
# 15: CARDINAL
# 15: CARDINAL
# 199: CARDINAL
# 11: CARDINAL
# 13: CARDINAL
# 654: CARDINAL
# 7: CARDINAL
# asia pacific: LOC
# 2018: DATE
# 2017: DATE
# asia pacific: LOC
# 2018: DATE
# asia pacific: LOC
# 2017: DATE
# 2016: DATE
# mac strength: PERSON
# asia pacific: LOC
# 2017: DATE
# 2018 2017 2016: DATE
# 2018 2017 2016: DATE
# 265: CARDINAL
# 595: CARDINAL
# 229: CARDINAL
# 234: CARDINAL
# 215: CARDINAL
# 639: CARDINAL
# 163: CARDINAL
# 141: CARDINAL
# 048: CARDINAL
# 131: CARDINAL
# 376: CARDINAL
# 101: CARDINAL
# 839: MONEY
# 88: CARDINAL
# 186: CARDINAL
# 84 263: CARDINAL
# 38: CARDINAL
# 39: CARDINAL
# 1: CARDINAL
# 2018: DATE
# 2017: DATE
# year year: DATE
# 2018 apple inc: MONEY
# 2018: DATE
# 10: CARDINAL
# 2017: DATE
# 2016: DATE
# year year: DATE
# 2017: DATE
# 38 5: CARDINAL
# quarter 2019: DATE
# 1a: CARDINAL
# 10: CARDINAL
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2017: DATE
# 2016: DATE
# 14: CARDINAL
# 236: CARDINAL
# 23: CARDINAL
# 11: CARDINAL
# 581: CARDINAL
# 15: CARDINAL
# 10: CARDINAL
# 5: CARDINAL
# 16: CARDINAL
# 9: DATE
# 194: CARDINAL
# 6: CARDINAL
# 7 7: CARDINAL
# 30: CARDINAL
# 26: CARDINAL
# 11: CARDINAL
# 24: CARDINAL
# 239: CARDINAL
# 12: CARDINAL
# 12 11: CARDINAL
# year year: DATE
# 2018: DATE
# 2017: DATE
# 2016: DATE
# year year: DATE
# 2018: DATE
# 2017: DATE
# 2016: DATE
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2017: DATE
# 2016: DATE
# 5: CARDINAL
# 686: CARDINAL
# 5: CARDINAL
# 201: CARDINAL
# 3 999: CARDINAL
# 3: CARDINAL
# 2: CARDINAL
# 1 456: CARDINAL
# 441: CARDINAL
# 133: CARDINAL
# 1 195: CARDINAL
# 2: CARDINAL
# 27: CARDINAL
# 1 348 year year: DATE
# 2018: DATE
# year year: DATE
# 2017: DATE
# 2: CARDINAL
# 2016: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# 2018 2017 2016: DATE
# 2018 2017: DATE
# 13: CARDINAL
# 15: CARDINAL
# 738: CARDINAL
# 15: CARDINAL
# 685: CARDINAL
# 18: CARDINAL
# 22 2017: DATE
# 35 21: DATE
# january 1 2018: DATE
# 24 5 2018 2018: DATE
# 2018: DATE
# 2018: DATE
# 2017 2016: DATE
# 35: CARDINAL
# 2018: DATE
# 2017: DATE
# 2018: DATE
# 2017: DATE
# 2016: DATE
# 2016 09: DATE
# 718: CARDINAL
# 2016 09 2018: DATE
# first third quarters: DATE
# 29 2018: DATE
# 6 3 billion: MONEY
# 426 million: CARDINAL
# quarterly: DATE
# august 30 2016: DATE
# european commission: ORG
# 1991: DATE
# irish: NORP
# two: CARDINAL
# june 2003: DATE
# 2014: DATE
# 13 1 billion: MONEY
# 1 2 billion: MONEY
# january 2015: DATE
# general court court: ORG
# union ireland: PERSON
# irish: NORP
# september 29 2018: DATE
# 24 2018: DATE
# ninth: ORDINAL
# altera corp v: ORG
# pronouncements hedging: PERSON
# august 2017: DATE
# 2017 12: DATE
# 815: CARDINAL
# 2017 12: DATE
# 2017 12: DATE
# 2017 12 first quarter 2020: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# october 2016: DATE
# 2016 16: DATE
# 740: CARDINAL
# 2016 16: DATE
# 2016 16 first quarter 2019: DATE
# 3 billion: CARDINAL
# 2016 16: DATE
# february 2016: DATE
# 2016 02: DATE
# 842: CARDINAL
# 2016 02: DATE
# 2016 02: DATE
# first quarter 2020: DATE
# 2016 02: DATE
# september 29 2018: DATE
# 2016 02: DATE
# january 2016: DATE
# 2016 01: DATE
# 825: CARDINAL
# 2016 01: DATE
# 2016 01 first quarter 2019: DATE
# 2016 01: DATE
# june 2016: DATE
# 2016 13: DATE
# 326: CARDINAL
# 2016 13: DATE
# 2016 13 first quarter 2021: DATE
# 2016 13: DATE
# 2014: DATE
# 2014 09: DATE
# 606: CARDINAL
# 2014 09: DATE
# 2014: CARDINAL
# 2014: CARDINAL
# 2014 09: DATE
# first quarter 2019: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# years ended september 29 2018: DATE
# 30 2017: DATE
# 2018 2017: DATE
# 2016: DATE
# 1 237: CARDINAL
# 895: CARDINAL
# 585: CARDINAL
# 41: CARDINAL
# 33: CARDINAL
# 783: CARDINAL
# 27: CARDINAL
# 010: CARDINAL
# 11: CARDINAL
# 11: CARDINAL
# 977: CARDINAL
# 8 105: CARDINAL
# 102: CARDINAL
# 103: CARDINAL
# 703: CARDINAL
# 78 927: CARDINAL
# 14 473: CARDINAL
# 27: CARDINAL
# 863: CARDINAL
# 2: CARDINAL
# 225: CARDINAL
# 66: CARDINAL
# 231: CARDINAL
# 16: CARDINAL
# 46: CARDINAL
# 446: CARDINAL
# 45 977: CARDINAL
# 2 87: DATE
# 876: CARDINAL
# 17: CARDINAL
# 20: CARDINAL
# 29 2018: DATE
# 20 3 billion: MONEY
# 2: CARDINAL
# 1: CARDINAL
# 8: CARDINAL
# 10: CARDINAL
# 2016 09: DATE
# next 12 months: DATE
# september 29 2018: DATE
# 13 1 billion: MONEY
# 1 2 billion: MONEY
# one: CARDINAL
# 2018: DATE
# 77 4 billion: MONEY
# 59 5 billion: MONEY
# 34 7 billion: MONEY
# 16 8 billion: MONEY
# 16 1 billion 2018: MONEY
# 32 4 billion: MONEY
# 13 3 billion: QUANTITY
# 87 9 billion 2018: MONEY
# 72 7 billion: QUANTITY
# 13 7 billion: MONEY
# 6 5 billion: MONEY
# 7 0 billion: MONEY
# 2017: DATE
# 64 2 billion: QUANTITY
# 48 4 billion: MONEY
# 20 8 billion: MONEY
# 4 9 billion: MONEY
# one: CARDINAL
# 1 9 billion: MONEY
# year: DATE
# 46 4 billion: MONEY
# 2017: DATE
# 33 1 billion: MONEY
# 12 5 billion: MONEY
# 18 0 billion 2017: MONEY
# 32 9 billion: MONEY
# 12 8 billion: MONEY
# 3 5 billion: MONEY
# 28 7 billion: MONEY
# 3 9 billion: MONEY
# 16 7 billion 2018: MONEY
# 2019: DATE
# september 29 2018: DATE
# 12 0 billion: MONEY
# 2 18: QUANTITY
# nine months apple inc 2018: DATE
# 10 k 30as september: DATE
# 29 2018: DATE
# 104 2 billion: MONEY
# 2018: DATE
# 7 0 billion: MONEY
# 6 5 billion: MONEY
# 8: CARDINAL
# 2: CARDINAL
# 5: CARDINAL
# 2018: DATE
# 405 5 million: CARDINAL
# 73 1 billion: QUANTITY
# two: CARDINAL
# 73 1 billion: MONEY
# 0 billion: CARDINAL
# 210 billion: CARDINAL
# 1 2018: CARDINAL
# 100 billion: MONEY
# 29 0 billion: MONEY
# 2018: DATE
# 10b5 1 exchange: MONEY
# 1 2018: CARDINAL
# quarterly: DATE
# 0: CARDINAL
# 63: CARDINAL
# 0 73: CARDINAL
# third quarter 2018: DATE
# annual: DATE
# quarterly: DATE
# september 29 2018: DATE
# millions: CARDINAL
# 2019payments: CARDINAL
# 2020: DATE
# 2022: DATE
# 2023: DATE
# 8: CARDINAL
# 18: CARDINAL
# 933: CARDINAL
# 17: CARDINAL
# 978: CARDINAL
# 58: CARDINAL
# 485: CARDINAL
# 104: ORG
# 1: CARDINAL
# 9: CARDINAL
# 627: CARDINAL
# 1 41: CARDINAL
# 183: CARDINAL
# 45: CARDINAL
# 200: CARDINAL
# 3: CARDINAL
# 66: CARDINAL
# 5: CARDINAL
# 942: CARDINAL
# 22: CARDINAL
# 281: CARDINAL
# 33 589: CARDINAL
# 55: CARDINAL
# 31: CARDINAL
# 27: CARDINAL
# 816: CARDINAL
# 199: CARDINAL
# 10 years: DATE
# multi year: DATE
# 150 days: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# september 29 2018: DATE
# third: ORDINAL
# 8: CARDINAL
# 9: CARDINAL
# third: ORDINAL
# k: GPE
# china: GPE
# 1: CARDINAL
# 8: CARDINAL
# 10: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# third: ORDINAL
# third: ORDINAL
# mana gement: ORG
# apple inc 2018: ORG
# 10: CARDINAL
# third: ORDINAL
# 150 days: DATE
# years: DATE
# 50: CARDINAL
# apple inc 2018: ORG
# 10 k 34management: CARDINAL
# december 22 2017: DATE
# 35 21: DATE
# january 1 2018: DATE
# 1 5 billion 2018: MONEY
# 2 0 billion: MONEY
# 1 2 billion: MONEY
# 1 7 billion: MONEY
# sec: ORG
# 118: CARDINAL
# 3: CARDINAL
# 8: CARDINAL
# 9: CARDINAL
# 8: CARDINAL
# 9: CARDINAL
# one: CARDINAL
# 7a: CARDINAL
# one: CARDINAL
# 100: CARDINAL
# september 29 2018: DATE
# 30 2017: DATE
# 100: CARDINAL
# 4 9 billion: MONEY
# apple inc 2018: ORG
# 10 k 35as september: DATE
# 29 2018: DATE
# 30 2017: DATE
# 102 5 billion: MONEY
# 100: CARDINAL
# september 29 2018: DATE
# 30 2017: DATE
# 399 million 376 million: MONEY
# 8: CARDINAL
# 5: CARDINAL
# 12 months: DATE
# thousands: CARDINAL
# 95: CARDINAL
# one day: DATE
# 592 million: CARDINAL
# september 29 2018: DATE
# one day: DATE
# 485 million: CARDINAL
# september 30 2017: DATE
# september 29 2018: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# 8: CARDINAL
# years ended september 29 2018: DATE
# 30 2017: DATE
# 2016 38: DATE
# years ended september 29 2018: DATE
# 30 2017: DATE
# 24 2016: DATE
# september 29 2018: DATE
# 30: CARDINAL
# 2017: DATE
# years ended september 29 2018: DATE
# 30 2017: DATE
# 41: CARDINAL
# years ended september 29 2018: DATE
# 30 2017: DATE
# 24: CARDINAL
# 42: CARDINAL
# 43: CARDINAL
# quarterly: DATE
# 64: CARDINAL
# 65: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# millions: CARDINAL
# thousands: CARDINAL
# years ended september 29 2018: DATE
# 30 2017: DATE
# 24 2016: TIME
# 265: CARDINAL
# 595: CARDINAL
# 229: CARDINAL
# 234: CARDINAL
# ...
# 17 0 billion: MONEY
# 2: CARDINAL
# 1 10: CARDINAL
# 2: CARDINAL
# 2023 2043: DATE
# 8: CARDINAL
# 3: CARDINAL
# 91 2014: DATE
# 12 0 billion: MONEY
# 2019 1: DATE
# 2: CARDINAL
# 1 61: CARDINAL
# 2: CARDINAL
# 2019 2044: DATE
# 48 2015: DATE
# 27 3 billion: MONEY
# 2019 2020: DATE
# 1 87: CARDINAL
# 0: CARDINAL
# 2019 2045: DATE
# 410: CARDINAL
# 0: CARDINAL
# 28: CARDINAL
# 24: CARDINAL
# 28: CARDINAL
# 24 9 billion: MONEY
# 2019 2021: DATE
# 3: CARDINAL
# 1: CARDINAL
# 2 44: CARDINAL
# 1 100: CARDINAL
# 2019 2046: DATE
# 059: CARDINAL
# 1: CARDINAL
# 78: CARDINAL
# 23: CARDINAL
# 645: CARDINAL
# 78 2017: DATE
# 28 7 billion: MONEY
# 2019 2022: DATE
# 250: CARDINAL
# 2: CARDINAL
# 41: CARDINAL
# 2: CARDINAL
# 250: CARDINAL
# 1: CARDINAL
# 1 81: CARDINAL
# 0: CARDINAL
# 4 300: CARDINAL
# 2019 2047: DATE
# 25: CARDINAL
# 617: DATE
# 4: CARDINAL
# 25: CARDINAL
# 705: CARDINAL
# 30 first quarter 2018: DATE
# 7 0 billion: MONEY
# 1 800: CARDINAL
# 2019 1: DATE
# 1 83: CARDINAL
# 2 000: CARDINAL
# 2020 1: DATE
# 2 03: CARDINAL
# 2 400: CARDINAL
# 2023: DATE
# 2 66: CARDINAL
# 2 750: CARDINAL
# 2025 1: DATE
# 3 000: CARDINAL
# 05: CARDINAL
# 3 750: CARDINAL
# 2047 1: DATE
# 250: CARDINAL
# 3 80: CARDINAL
# 104: CARDINAL
# 218 225: CARDINAL
# 1 456 93: CARDINAL
# 8: CARDINAL
# 93: CARDINAL
# 735: CARDINAL
# 97: CARDINAL
# 207: CARDINAL
# japanese: NORP
# 29 2018: DATE
# 30 2017: DATE
# 811 million: CARDINAL
# 2: CARDINAL
# 3 0 billion 2 2 billion 1 4 billion: MONEY
# 2018 2017 2016: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# september 29 2018: DATE
# millions: CARDINAL
# 8 797 2020: DATE
# 183: CARDINAL
# 2022: DATE
# 8: CARDINAL
# 2023: DATE
# 9: CARDINAL
# 395: CARDINAL
# 58 485: CARDINAL
# 104: CARDINAL
# 29 2018: DATE
# 30: CARDINAL
# 2017: DATE
# 2: CARDINAL
# 103 2 billion: MONEY
# 106 1 billion: MONEY
# 6: CARDINAL
# 2018: DATE
# 405 5 million: CARDINAL
# 73 1 billion: QUANTITY
# two: CARDINAL
# 73 1 billion: MONEY
# 0 billion: CARDINAL
# 210 billion: CARDINAL
# 1 2018: CARDINAL
# 100 billion: MONEY
# 29 0 billion: MONEY
# 2018: DATE
# 10b5 1 securities exchange: MONEY
# 1934: CARDINAL
# 7: CARDINAL
# 2018 2017: DATE
# millions: CARDINAL
# 2018 2017: DATE
# 214: CARDINAL
# 662: PRODUCT
# 70 654: CARDINAL
# 344: CARDINAL
# 638: CARDINAL
# 2: CARDINAL
# 1 952: CARDINAL
# 20 99: CARDINAL
# 466: CARDINAL
# 2: CARDINAL
# apple inc 2018: ORG
# 10 k 57the: DATE
# 2018 2017: DATE
# millions: CARDINAL
# september 24: DATE
# 578: CARDINAL
# 38: CARDINAL
# 301 1: CARDINAL
# 887: CARDINAL
# 1 952: CARDINAL
# 99: CARDINAL
# 2 051: CARDINAL
# 77 3 460 380: DATE
# 224: CARDINAL
# 162: CARDINAL
# 846: CARDINAL
# september 30: DATE
# 2017: DATE
# 354: CARDINAL
# 124: CARDINAL
# 328 150: CARDINAL
# 524: CARDINAL
# 563: CARDINAL
# 4: CARDINAL
# 415: CARDINAL
# 486: CARDINAL
# 1 253: CARDINAL
# 1 177: CARDINAL
# 525: CARDINAL
# 3: CARDINAL
# 026: CARDINAL
# 1 176: DATE
# 29: CARDINAL
# 278: CARDINAL
# september 29 2018: DATE
# 810: CARDINAL
# 3: CARDINAL
# 209: CARDINAL
# 3: CARDINAL
# 4: CARDINAL
# 2018 02 2018: DATE
# 8: CARDINAL
# 2014: DATE
# second: ORDINAL
# quarter 2014: DATE
# 2014: DATE
# 2014: DATE
# 2003: DATE
# 2003: DATE
# 2014: DATE
# 2014: DATE
# four years: DATE
# 2014: DATE
# two: CARDINAL
# 2014: DATE
# two: CARDINAL
# 2014: DATE
# ders: CARDINAL
# ders: CARDINAL
# ders: CARDINAL
# 2014: DATE
# 385 million: CARDINAL
# 2003: DATE
# 2003: DATE
# 2014: DATE
# september 29 2018: DATE
# 2 million: CARDINAL
# 2014: DATE
# apple inc non: ORG
# apple inc non: ORG
# annual: DATE
# annual: DATE
# annual: DATE
# two: CARDINAL
# november 12 2027: DATE
# ders: CARDINAL
# ders: CARDINAL
# ders: CARDINAL
# september 29 2018: DATE
# 1 1 million: CARDINAL
# apple inc 2018: ORG
# 10 k 58rule: QUANTITY
# three months ended september 29 2018: DATE
# 16: CARDINAL
# angela ahrendts timothy cook: PERSON
# chris kondo: PERSON
# maestri daniel riccio philip: ORG
# jeffrey williams: PERSON
# 10b5 1: DATE
# 85: CARDINAL
# six month: DATE
# 10: CARDINAL
# 25 000: CARDINAL
# year september 29 2018: DATE
# 5 million: CARDINAL
# 401: CARDINAL
# 401: CARDINAL
# 401: CARDINAL
# 401: CARDINAL
# irs: ORG
# annual: DATE
# 18 500: CARDINAL
# year 2018: DATE
# 50 100: CARDINAL
# 6: CARDINAL
# 2018 2017: DATE
# 2016: DATE
# thousands: CARDINAL
# millions: CARDINAL
# 26 2015: DATE
# 85: CARDINAL
# 49: CARDINAL
# 468: CARDINAL
# 109 28: CARDINAL
# 46: CARDINAL
# 313: CARDINAL
# 84 44: DATE
# 5: CARDINAL
# 96: CARDINAL
# 48: CARDINAL
# 99: CARDINAL
# 089: CARDINAL
# 97 54: DATE
# 50: CARDINAL
# 45: CARDINAL
# 735: CARDINAL
# 48: CARDINAL
# 5: CARDINAL
# 106: CARDINAL
# september 30: DATE
# 2017: DATE
# 97: CARDINAL
# 571: CARDINAL
# 110 33: CARDINAL
# 45: CARDINAL
# 351: CARDINAL
# 162 86: CARDINAL
# 44: CARDINAL
# 718: CARDINAL
# 111: CARDINAL
# 24: CARDINAL
# 6: CARDINAL
# 29 2018: DATE
# 155: CARDINAL
# 60: CARDINAL
# 20: CARDINAL
# 803: CARDINAL
# 7 6 billion: MONEY
# 2018 2017 2016: DATE
# 2018 2017: DATE
# 2016: DATE
# approximately 16 0 million: QUANTITY
# 2018 2017 2016: DATE
# 2018 2017 2016: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# 2018 2017: DATE
# 2018 2017: DATE
# 2016: DATE
# 1: CARDINAL
# 877 769: CARDINAL
# 2: CARDINAL
# 1 889: CARDINAL
# 1: CARDINAL
# 1: CARDINAL
# 1 552: CARDINAL
# 5: CARDINAL
# 340: CARDINAL
# 4: CARDINAL
# 840: CARDINAL
# 1 9 billion 1 6 billion 1 4 billion: MONEY
# 2018 2017 2016: DATE
# 29 2018: DATE
# 9 4 billion: MONEY
# 2 5 years: DATE
# 9: CARDINAL
# 2018 2017: DATE
# 2018 2017 2016: DATE
# 3: CARDINAL
# 780: CARDINAL
# 4: CARDINAL
# 322: CARDINAL
# 4 663: CARDINAL
# 3 973: CARDINAL
# 4: CARDINAL
# 3 692: CARDINAL
# 702: CARDINAL
# third: ORDINAL
# third: ORDINAL
# k: GPE
# china: GPE
# apple inc 2018: ORG
# 10: CARDINAL
# one: CARDINAL
# asia mac: LOC
# u ireland: GPE
# 150 days: DATE
# september 29 2018: DATE
# 9 6 billion: MONEY
# 10 years: DATE
# multi year: DATE
# 1 2 billion 1 1 billion 939 million: MONEY
# 2018 2017 2016: DATE
# one year: DATE
# 29 2018: DATE
# millions: CARDINAL
# 2019: CARDINAL
# 2021: DATE
# 1: CARDINAL
# 218: CARDINAL
# 2022: DATE
# 1: CARDINAL
# 2023: DATE
# 3 984: CARDINAL
# 9 627: CARDINAL
# one year: DATE
# 29 2018: DATE
# millions: CARDINAL
# 2019: DATE
# 2020: DATE
# 2021: DATE
# 749: CARDINAL
# 1: CARDINAL
# 268: CARDINAL
# 66: CARDINAL
# 9 328: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 1a: CARDINAL
# 10: CARDINAL
# 3: CARDINAL
# one: CARDINAL
# virnetx inc: ORG
# two: CARDINAL
# eastern district: LOC
# texas: GPE
# texas district court: ORG
# four: CARDINAL
# virnetx ii: EVENT
# september 30 2016: DATE
# 302 million: CARDINAL
# 440 million: CARDINAL
# april 11 2018: DATE
# 503 million: CARDINAL
# texas district court: ORG
# january 20 2017: DATE
# california: GPE
# beginning second quarter 2017: DATE
# 10: CARDINAL
# china: GPE
# japan: GPE
# asia pacific americas: LOC
# north south america europe: LOC
# european: NORP
# india: GPE
# middle east africa: LOC
# china: GPE
# hong kong: GPE
# taiwan: GPE
# asia pacific: LOC
# asian: NORP
# one: CARDINAL
# 1: CARDINAL
# third: ORDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 2018 2017: DATE
# 2018 2017: DATE
# 2016: DATE
# 112: CARDINAL
# 96: CARDINAL
# 600: CARDINAL
# 34: CARDINAL
# 30: CARDINAL
# 172 europe: LOC
# 62: CARDINAL
# 54: CARDINAL
# 938: CARDINAL
# 49: CARDINAL
# 952: CARDINAL
# 19: CARDINAL
# 16: CARDINAL
# 514: CARDINAL
# 15: CARDINAL
# 348: CARDINAL
# 51: CARDINAL
# 942: CARDINAL
# 44: DATE
# 764: CARDINAL
# 48: CARDINAL
# 19: CARDINAL
# 17: CARDINAL
# 18: CARDINAL
# japan: GPE
# 21: CARDINAL
# 17: CARDINAL
# 16 928: CARDINAL
# 9: CARDINAL
# asia pacific: LOC
# 17: CARDINAL
# 15: CARDINAL
# 199: CARDINAL
# 13 654: CARDINAL
# 6: CARDINAL
# 5: DATE
# 2018 2017 2016: DATE
# millions 2018: DATE
# 2016: DATE
# 90: CARDINAL
# 77: CARDINAL
# 74 301: CARDINAL
# 14: CARDINAL
# 11: CARDINAL
# 581: CARDINAL
# 10: CARDINAL
# 045: CARDINAL
# 5: CARDINAL
# 4: DATE
# 232: CARDINAL
# 70: CARDINAL
# 61: CARDINAL
# 344: CARDINAL
# 60: CARDINAL
# 024: CARDINAL
# china: GPE
# 10: CARDINAL
# 2018 2017: DATE
# 2016: DATE
# 10: CARDINAL
# 2018 2017 2016: DATE
# 2018 2017: DATE
# 2016: DATE
# 29 2018: DATE
# 30 2017: DATE
# millions 2018 2017 2016: DATE
# 98: CARDINAL
# 84: CARDINAL
# 339: CARDINAL
# 942: CARDINAL
# 44: DATE
# 764: CARDINAL
# 48: CARDINAL
# 492: CARDINAL
# 115 592: CARDINAL
# 131: CARDINAL
# 91 480: CARDINAL
# 265: CARDINAL
# 595: CARDINAL
# 229: CARDINAL
# 234: CARDINAL
# 215: CARDINAL
# 2018 2017: DATE
# 23: CARDINAL
# 20: CARDINAL
# 1 13: CARDINAL
# 268: CARDINAL
# 10: CARDINAL
# 211: CARDINAL
# 4: CARDINAL
# 41: CARDINAL
# 33: CARDINAL
# 783: CARDINAL
# china: GPE
# hong kong: GPE
# taiwan: GPE
# china: GPE
# apple inc 2018: ORG
# 10: CARDINAL
# 2018 2017 2016: DATE
# millions 2018 2017: DATE
# 2016: DATE
# 1: CARDINAL
# 699: CARDINAL
# 141: CARDINAL
# 136: CARDINAL
# 700: CARDINAL
# 1 18: DATE
# 19: DATE
# 222: ORG
# 20: CARDINAL
# 1 25: CARDINAL
# 25: DATE
# 22: CARDINAL
# 831: CARDINAL
# 2 37: DATE
# 29: CARDINAL
# 980: CARDINAL
# 24 348: CARDINAL
# 1 3: DATE
# 12: CARDINAL
# 863: CARDINAL
# 11 132: CARDINAL
# 265: CARDINAL
# 595: CARDINAL
# 229: CARDINAL
# 234: CARDINAL
# 215: CARDINAL
# 1: CARDINAL
# 2: CARDINAL
# 2018: DATE
# one: CARDINAL
# 236 million: CARDINAL
# 2017: DATE
# one: CARDINAL
# 640 million: CARDINAL
# 3: CARDINAL
# apple branded third party: ORG
# 11: CARDINAL
# quarterly: DATE
# quarterly: DATE
# four quarters 2018 2017: DATE
# millions: CARDINAL
# fourth quarter third quarter second quarter first quarter 2018: DATE
# 62: CARDINAL
# 265: CARDINAL
# 61: DATE
# 137: CARDINAL
# 88: CARDINAL
# 293: CARDINAL
# 24 084: CARDINAL
# 20: CARDINAL
# 23: CARDINAL
# 422: CARDINAL
# 33 912: CARDINAL
# 14: CARDINAL
# 13: CARDINAL
# 822: CARDINAL
# 20: CARDINAL
# 065: CARDINAL
# 1: CARDINAL
# 2: CARDINAL
# 2: CARDINAL
# 2: CARDINAL
# 2: CARDINAL
# 89 fourth quarter third quarter second quarter first quarter 2017: DATE
# 52: CARDINAL
# 579: CARDINAL
# 45: CARDINAL
# 408: CARDINAL
# 52: CARDINAL
# 896: CARDINAL
# 78 351: CARDINAL
# 19: CARDINAL
# 17: DATE
# 20: CARDINAL
# 591: CARDINAL
# 30 176: CARDINAL
# 10: CARDINAL
# 11: CARDINAL
# 17 891: CARDINAL
# 1: CARDINAL
# 2: CARDINAL
# 2: CARDINAL
# quarterly: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# 64report: CARDINAL
# apple inc opinion financial: ORG
# apple inc: ORG
# september 29 2018: DATE
# 30 2017: DATE
# three years period ended: DATE
# 29 2018: DATE
# september 29 2018: DATE
# 30 2017: DATE
# three years period ended: DATE
# 2018: DATE
# pcaob apple inc internal control financial: ORG
# september 29 2018: DATE
# 2013: DATE
# november 5 2018: DATE
# apple inc management: ORG
# apple inc financial: ORG
# apple inc accordance: ORG
# apple inc auditor: ORG
# 2009: DATE
# san jose: GPE
# california: GPE
# november 5 2018: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# apple inc opinion internal control financial: ORG
# apple inc internal control financial: ORG
# september 29 2018: DATE
# 2013: DATE
# apple inc maintained: ORG
# september 29 2018: DATE
# pcaob consolidated balance sheets apple inc: ORG
# september 29 2018: DATE
# 30 2017: DATE
# three years period ended: DATE
# 29 2018: DATE
# november 5 2018: DATE
# apple inc management: ORG
# annual: DATE
# apple inc internal control financial: ORG
# apple inc accordance: ORG
# pcaob conducted audit accordance standards pcaob standards require: ORG
# 1: CARDINAL
# 2: CARDINAL
# 3: CARDINAL
# california: GPE
# november 5 2018: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# 9a: CARDINAL
# 13a 15 e 15d 15: DATE
# september 29 2018: DATE
# sec: ORG
# annual: DATE
# 13a 15: DATE
# 2013: DATE
# september 29 2018: DATE
# 8: CARDINAL
# fourth quarter 2018: DATE
# 13a 15 15d 15: DATE
# 9b: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 10: CARDINAL
# 2019: DATE
# sec: ORG
# 120 days: DATE
# 29 2018: DATE
# 2019: DATE
# annual: DATE
# 8: CARDINAL
# sec: ORG
# 11: CARDINAL
# 2018: DATE
# 2019: DATE
# sec: ORG
# 120 days: DATE
# 29 2018: DATE
# 12: CARDINAL
# 2019: DATE
# sec: ORG
# 120 days: DATE
# 29 2018: DATE
# 13: CARDINAL
# 2019: DATE
# sec: ORG
# 120 days: DATE
# 29 2018: DATE
# 14: CARDINAL
# 2019: DATE
# sec: ORG
# 120 days: DATE
# 29 2018: DATE
# 2018: DATE
# 10: CARDINAL
# 15: CARDINAL
# 1: CARDINAL
# years ended september 29 2018: DATE
# 30 2017: DATE
# 2016 38: DATE
# years ended september 29 2018: DATE
# 30 2017: DATE
# 24 2016: DATE
# september 29 2018: DATE
# 30: CARDINAL
# 2017: DATE
# years ended september 29 2018: DATE
# 30 2017: DATE
# 41: CARDINAL
# years ended september 29 2018: DATE
# 30 2017: DATE
# 24: CARDINAL
# 42: CARDINAL
# 43: CARDINAL
# quarterly: DATE
# 64: CARDINAL
# 65 2: CARDINAL
# 10: CARDINAL
# 3: CARDINAL
# 601: CARDINAL
# 1: CARDINAL
# 3 1: CARDINAL
# june 6 2014: DATE
# 3 2: CARDINAL
# december 13 2016: DATE
# 16: CARDINAL
# 10: CARDINAL
# 06: CARDINAL
# 4 2: CARDINAL
# april 29 2013: DATE
# new york mellon trust company n: ORG
# 3: CARDINAL
# 29: CARDINAL
# 13: CARDINAL
# 4: CARDINAL
# 3: CARDINAL
# 3 2013: DATE
# 2016: DATE
# 2018: DATE
# 45: CARDINAL
# 2016 1 00: DATE
# 2018: DATE
# 2023 3 85: DATE
# 2043 8: DATE
# 4: CARDINAL
# 4: CARDINAL
# 6 2014: DATE
# 2017: DATE
# 2019 1: DATE
# 2017 2: DATE
# 2019 2 85: DATE
# 2021: DATE
# 3 45: CARDINAL
# 2024 4 45: DATE
# 2044 8: DATE
# 4: CARDINAL
# 5: CARDINAL
# november 10 2014: DATE
# 1 000: CARDINAL
# 2022: CARDINAL
# 1 625: CARDINAL
# 2026 8: DATE
# 4 1 11: DATE
# 6: CARDINAL
# february 9 2015: DATE
# 2020: CARDINAL
# 2020 2 15: DATE
# 2022: DATE
# 2 50: CARDINAL
# 2025 3 45: DATE
# 2045 8: DATE
# 4: CARDINAL
# 13 2015: DATE
# 2017: DATE
# 2020: CARDINAL
# 2017 2: DATE
# 2020 2 700: DATE
# 2022: DATE
# 3: CARDINAL
# 200: CARDINAL
# 2025 4 375: DATE
# 2045 8: DATE
# 4: CARDINAL
# 13: CARDINAL
# 15: CARDINAL
# 8: CARDINAL
# june 10 2015: DATE
# 0 350: CARDINAL
# 2020 8: DATE
# apple inc 2018: ORG
# 10: CARDINAL
# 69: CARDINAL
# 9: CARDINAL
# july 31 2015: DATE
# 3 05: CARDINAL
# 2029 3 60: DATE
# 2042: DATE
# 4 1: DATE
# 10: CARDINAL
# september 17 2015: DATE
# 1 375: CARDINAL
# 2024 2: DATE
# 2027 8: DATE
# 4 1: DATE
# 11: CARDINAL
# february 23 2016: DATE
# 2019: DATE
# 2021 1 300: DATE
# 2018 1: DATE
# 2019 2: DATE
# 250: CARDINAL
# 2021 2: DATE
# 850: CARDINAL
# 2023 3 250: DATE
# 2026 4: DATE
# 2036: DATE
# 4: CARDINAL
# 650: CARDINAL
# 2046 8: DATE
# 4: CARDINAL
# 16: CARDINAL
# 12: CARDINAL
# 1: CARDINAL
# march 24 2016: DATE
# 4: CARDINAL
# 13: CARDINAL
# june 22 2016: DATE
# 4 15: CARDINAL
# 2046 8: DATE
# 4: CARDINAL
# 22: CARDINAL
# 16: CARDINAL
# 14: CARDINAL
# august 4 2016: DATE
# 2019 1: DATE
# 2019 1: DATE
# 2021: CARDINAL
# 2 450: CARDINAL
# 2026 3: DATE
# 850: CARDINAL
# 2046 8: DATE
# 4 1 8 4: DATE
# 15: CARDINAL
# february 9 2017: DATE
# 2019: DATE
# 2020: DATE
# 2022 1 550: DATE
# 2019 1: DATE
# 2020: CARDINAL
# 2022 3: DATE
# 2024 3 350: DATE
# 2027: CARDINAL
# 250: CARDINAL
# 2047 8: DATE
# 4: CARDINAL
# 16: CARDINAL
# march 3 2017: DATE
# 4 300: CARDINAL
# 2047 8: DATE
# 17: CARDINAL
# 11 2017: DATE
# 2020: DATE
# 2022 1 800: DATE
# 2020 2 300: DATE
# 2022 2 850: DATE
# 2024: CARDINAL
# 3: CARDINAL
# 200: CARDINAL
# 2027 8: DATE
# 4: CARDINAL
# 17: CARDINAL
# 18: CARDINAL
# 24 2017: DATE
# 0 875: CARDINAL
# 2025 1 375: DATE
# 2029 8: DATE
# 4: CARDINAL
# 19: CARDINAL
# june 20 2017: DATE
# 3 000: CARDINAL
# 2027 8: DATE
# 20: CARDINAL
# august 18 2017: DATE
# 2 513: CARDINAL
# 2024 8: DATE
# 4 1: DATE
# 21: CARDINAL
# september 12 2017: DATE
# 1 500: CARDINAL
# 2019 2: DATE
# 2022: DATE
# 2: CARDINAL
# 2027: CARDINAL
# 750: CARDINAL
# 2047 8: DATE
# 4: CARDINAL
# 22: CARDINAL
# november 13 2017: DATE
# 1 800: CARDINAL
# 2019 2: DATE
# 2020 2 400: DATE
# 2023 2: DATE
# 750: CARDINAL
# 2025 3: DATE
# 2027: CARDINAL
# 750: CARDINAL
# 2047 8: DATE
# 4 1: DATE
# 13: CARDINAL
# 17: CARDINAL
# apple inc deferred: ORG
# 8: CARDINAL
# 18: CARDINAL
# 10 2015: DATE
# 15: CARDINAL
# 10: CARDINAL
# apple inc non: ORG
# february 13 2018: DATE
# 10: CARDINAL
# 4 2003: DATE
# february 25: DATE
# 2003: DATE
# november 16 2010: DATE
# 10 q 10 10: DATE
# october 1 2017: DATE
# 10: CARDINAL
# 17: CARDINAL
# 2014: DATE
# august 26 2014 10: DATE
# 10 8: CARDINAL
# 2014: DATE
# august 26 2014 10: DATE
# 27: CARDINAL
# apple inc 2018: ORG
# 10: CARDINAL
# 70: CARDINAL
# 10 9: CARDINAL
# august 26 2014: DATE
# august 26 2014 10: DATE
# 10 13: DATE
# 27: CARDINAL
# 10 10: CARDINAL
# 2014: DATE
# october 5 2015: DATE
# 26: CARDINAL
# 16: CARDINAL
# 10 11: CARDINAL
# 2014: DATE
# october 5 2015: DATE
# 26: CARDINAL
# 16: CARDINAL
# 10 12: CARDINAL
# 2014: DATE
# october 14 2016 10: DATE
# 10 18: DATE
# 16: CARDINAL
# 10 13: CARDINAL
# 2014: DATE
# october 14 2016 10: DATE
# 14: CARDINAL
# 2014: DATE
# september 26 2017: DATE
# 10: CARDINAL
# 9: CARDINAL
# 15: CARDINAL
# 2014: DATE
# september 26 2017: DATE
# 10: CARDINAL
# 10 21: DATE
# 9: CARDINAL
# 17: CARDINAL
# 16: CARDINAL
# february 13 2018: DATE
# 18: CARDINAL
# 17: CARDINAL
# 2014: DATE
# august 21 2018: DATE
# 10 18: CARDINAL
# 2014: DATE
# august 21 2018: DATE
# 21 1: DATE
# 23: CARDINAL
# 24: CARDINAL
# 1: CARDINAL
# annual: DATE
# 10: CARDINAL
# 31 1: DATE
# 13a 14 15d: DATE
# 31: CARDINAL
# 13a 14 15d: DATE
# 32 1: CARDINAL
# 1350: DATE
# 101: CARDINAL
# 101: CARDINAL
# 101: CARDINAL
# 101: CARDINAL
# 101: CARDINAL
# 1: CARDINAL
# 601: CARDINAL
# 4: CARDINAL
# sec: ORG
# 16: CARDINAL
# 10: CARDINAL
# apple inc 2018: ORG
# 10 k 71signa: DATE
# 13: CARDINAL
# 1934: DATE
# 5 2018: DATE
# apple inc luca: ORG
# timothy cook: PERSON
# annual: DATE
# 10: CARDINAL
# 1934: DATE
# timothy cook: PERSON
# november 5 2018: DATE
# november 5 2018: DATE
# chris kondo: PERSON
# november 5 2018: DATE
# chris: PERSON
# kondo james bell: PERSON
# 5 2018: DATE
# al gore: PERSON
# 5 2018: DATE
# al gore: PERSON
# robert iger: PERSON
# 5 2018: DATE
# robert: PERSON
# andrea jung: PERSON
# 5 2018: DATE
# andrea jung arthur levinson: PERSON
# 5 2018: DATE
# arthur levinson ronald: PERSON
# 5 2018: DATE
# wagner: ORG
# 5 2018: DATE
# wagner apple inc 2018: ORG
# 10: CARDINAL
# 72: CARDINAL

# %%
# creating annotated training data

training_data = [
    {
        "text": "Apple Inc. reported a net profit of $200 billion in Q4 2023.",
        "entities": [(0, 9, "ORG"), (30, 41, "MONEY"), (45, 53, "DATE")]
    },
    {
        "text": "Microsoft Corp's revenue grew to $150 billion, while Google earned $180 billion.",
        "entities": [(0, 15, "ORG"), (36, 47, "MONEY"), (55, 61, "ORG"), (68, 79, "MONEY")]
    },
    {
        "text": "AAPL stock rose by 7% after the announcement.",
        "entities": [(0, 4, "ORG"), (17, 19, "PERCENT")]
    },
    {
        "text": "Tesla's Q2 2023 earnings increased by 10%, totaling $50 billion.",
        "entities": [(0, 5, "ORG"), (7, 14, "DATE"), (36, 39, "PERCENT"), (50, 60, "MONEY")]
    },
    {
        "text": "Amazon Web Services dominates the cloud market with revenue of $62 billion.",
        "entities": [(0, 19, "ORG"), (63, 73, "MONEY")]
    },
    {
        "text": "Alphabet Inc. reported revenue of $134 billion for fiscal year 2022.",
        "entities": [(0, 12, "ORG"), (30, 41, "MONEY"), (59, 63, "DATE")]
    },
]

# function to validate and prepare training data
from spacy.tokens import DocBin

def validate_training_data(data):
    """
    this function ensures training data is in the correct format
    and converts it into a spacy-compatible binary file
    """
    nlp = spacy.blank("en")  # create a blank spacy model
    doc_bin = DocBin()  # initialize spacy's binary data container
    for record in data:
        if "text" in record and "entities" in record:
            text = record["text"]
            entities = record["entities"]
            doc = nlp.make_doc(text)  # create a document object
            spans = [doc.char_span(start, end, label) for start, end, label in entities if doc.char_span(start, end, label)]
            doc.ents = spans  # assign the entities to the doc
            doc_bin.add(doc)  # add the doc to the binary container
    return doc_bin

# validating and saving training data
doc_bin = validate_training_data(training_data)
doc_bin.to_disk("training.spacy")  # save the training data

# %%
# generating the spacy config file using cli
# !python -m spacy init config config.cfg --lang en --pipeline ner --force

# training the model using spacy's cli
# !python -m spacy train config.cfg --output ./output --paths.train training.spacy --paths.dev training.spacy
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy
# ℹ Saving to output directory: output
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     40.70    0.00    0.00    0.00    0.00
# 200     200         36.38    884.92  100.00  100.00  100.00    1.00
# 400     400          0.00      0.00  100.00  100.00  100.00    1.00
# 600     600          0.00      0.00  100.00  100.00  100.00    1.00
# 800     800          0.00      0.00  100.00  100.00  100.00    1.00
# 1000    1000          0.00      0.00  100.00  100.00  100.00    1.00
# 1200    1200          0.00      0.00  100.00  100.00  100.00    1.00
# 1400    1400          0.00      0.00  100.00  100.00  100.00    1.00
# 1600    1600          0.00      0.00  100.00  100.00  100.00    1.00
# 1800    1800          0.00      0.00  100.00  100.00  100.00    1.00
# ✔ Saved pipeline to output directory
# output/model-last

# %% [markdown]
# # 4. Visualization and Deployment
#
# ### Visualization:
# - Used SpaCy’s `displacy` tool to highlight extracted entities in the text.
# - Example:
#   - Input: "Apple Inc. reported revenue of $123 billion."
#   - Highlighted Output:
#     - **Apple Inc.** (ORG)
#     - **$123 billion** (MONEY)
#
# ### Deployment:
# - Created an interactive web app using **Streamlit**.
# - Features:
#   1. Accepts text input from the user.
#   2. Highlights entities like company names, dates, and monetary values.
#   3. Displays extracted entities in an easy-to-read format.
#
# ### Benefits:
# 1. Real-time extraction of financial entities.
# 2. Easy to extend for new reports or companies.
# 3. User-friendly interface.

# %%
import spacy

# loading the trained model
nlp = spacy.load("./output/model-best")

# sample text to test the model
test_text = "Microsoft Inc. reported revenue of $123 billion, while AAPL stock surged by 5%."

# process the test text with the trained model
doc = nlp(test_text)

# display extracted entities
print("extracted entities:")
for ent in doc.ents:
    print(f"text: {ent.text}, label: {ent.label_}")

# visualize the entities using spacy's displacy
from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# extracted entities:
# text: AAPL, label: ORG
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Microsoft Inc. reported revenue of $123 billion, while
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AAPL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  stock surged by 5%.</div></span>

# %%
# !pip install streamlit spacy
# !pip install pyngrok
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.41.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.10.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.21.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.11/dist-packages (7.2.3)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)

# %%
# Create and save app.py
app_code = """
import streamlit as st
import spacy
from spacy import displacy

# Load the trained model
@st.cache_resource
def load_model():
    return spacy.load("./output/model-best")

nlp = load_model()

# Streamlit interface
st.title("Financial NER System")
st.write("This app extracts key entities from financial text such as company names, monetary values, and events.")

# User input
user_input = st.text_area("Enter financial text:", height=150)

if st.button("Extract Entities"):
    if user_input.strip():  # Check if text is provided
        # Process the input text
        doc = nlp(user_input)

        # Display extracted entities
        st.write("### Extracted Entities:")
        for ent in doc.ents:
            st.write(f"- **{ent.text}**: {ent.label_}")

        # Visualize the entities using SpaCy's displaCy
        st.write("### Visualization:")
        html = displacy.render(doc, style="ent", jupyter=False)
        st.components.v1.html(html, height=300, scrolling=True)
    else:
        st.error("Please enter some text to extract entities.")
"""

with open("app.py", "w") as file:
    file.write(app_code)
print("app.py saved!")
# Out:
# app.py saved!

# %% [markdown]
# ## 5. Presentation and Documentation
#
# ### Observations and Errors
# 1. **Partial Entity Recognition**:
#    - The trained model identified some entities, such as company names and monetary values, but missed or partially recognized others.
#    - Example:
#      Input: `"Microsoft Inc. reported revenue of $123 billion, while AAPL stock surged by 5%."`
#      Extracted Entities:
#      ```
#      - Entity: Microsoft Inc., Label: ORG
#      - Entity: $123 billion, Label: MONEY
#      ```
#      The entity `AAPL` was only partially recognized, missing the stock-related context.
#
# 2. **Limited Dataset**:
#    - The model was trained on a small dataset comprising only two financial reports with manually annotated examples.
#    - This limited the model’s ability to generalize to unseen financial text.
#
# 3. **Annotation Challenges**:
#    - Manual annotation was time-consuming and error-prone, especially for complex financial jargon and domain-specific terms.
#
# ---
#
# ### Improvements and Future Directions
#
# 1. **Expand Dataset**:
#    - Collect additional financial reports from diverse companies and sources (e.g., SEC filings, news websites, earnings calls).
#    - Increase the variety of text formats and contexts to improve the model's robustness.
#
# 2. **Automate Annotation**:
#    - Utilize weak supervision or semi-supervised learning for faster annotation.
#    - Use pre-trained models like `FinBERT` to generate initial annotations and refine them manually.
#
# 3. **Improve Model Performance**:
#    - Fine-tune the system with domain-specific pre-trained models, such as:
#      - `FinBERT`
#      - Financial SpaCy pipelines
#    - Experiment with transformer-based models for better context understanding.
#
# 4. **Add New Entity Types**:
#    - Extend the system to include additional entity types, such as:
#      - Stock tickers (e.g., `AAPL`)
#      - Financial events (e.g., `mergers`, `IPOs`)
#      - Percentages (e.g., `5%`)
#    - Create detailed annotation guidelines for these entities.
#
# 5. **Visualization and User Interface**:
#    - Enhance the Streamlit app to:
#      - Accept larger text inputs.
#      - Provide filters for specific entities.
#      - Offer interactive visualization with entity details.
#
# 6. **Real-World Deployment**:
#    - Deploy the system as an API or web dashboard.
#    - Test the system with real-world financial text and collect feedback for iterative improvements.
#
# ---
#
# ### Summary of Findings
#
# 1. **Challenges**:
#    - Limited dataset and manual annotation hampered the system’s performance.
#    - Entity recognition was partially successful due to insufficient domain-specific training.
#
# 2. **Key Results**:
#    - The system effectively extracted some entities (e.g., company names and monetary values).
#    - Entity visualization provided insights into their placement within the text.
#
# 3. **Future Scope**:
#    - Automate annotations and expand the dataset for scalability.
#    - Transition to advanced transformer-based models for improved accuracy and contextual understanding.
